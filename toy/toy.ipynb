# %%
from src.eval import plot_temperature_triptych

_ = plot_temperature_triptych(
		dataset_name="composed",
		lam=0.55,
		n_replicas=4,
		replica_swaps=True,
		swap_algorithm={},
	)

# %%
# !python -m src.eval --lam 0.25 --n_replicas 4 --replica_exchange
# Out:
# t 99 | lam 0.75↔1.25 | integral -0.545 | acceptance 0.614
# t 98 | lam 0.25↔0.75 | integral 0.381 | acceptance 0.695
# t 98 | lam 1.25↔1.75 | integral -0.205 | acceptance 0.644
# t 97 | lam 0.75↔1.25 | integral 0.341 | acceptance 0.712
# t 96 | lam 0.25↔0.75 | integral 0.417 | acceptance 0.739
# t 96 | lam 1.25↔1.75 | integral -0.438 | acceptance 0.641
# t 95 | lam 0.75↔1.25 | integral 0.298 | acceptance 0.736
# t 94 | lam 0.25↔0.75 | integral 0.364 | acceptance 0.765
# t 94 | lam 1.25↔1.75 | integral -0.674 | acceptance 0.630
# t 93 | lam 0.75↔1.25 | integral 0.171 | acceptance 0.748
# t 92 | lam 0.25↔0.75 | integral 0.270 | acceptance 0.781
# t 92 | lam 1.25↔1.75 | integral -0.830 | acceptance 0.620
# t 91 | lam 0.75↔1.25 | integral 0.081 | acceptance 0.755
# t 90 | lam 0.25↔0.75 | integral 0.212 | acceptance 0.797
# t 90 | lam 1.25↔1.75 | integral -0.972 | acceptance 0.615
# t 89 | lam 0.75↔1.25 | integral -0.012 | acceptance 0.760
# t 88 | lam 0.25↔0.75 | integral 0.141 | acceptance 0.808
# t 88 | lam 1.25↔1.75 | integral -1.066 | acceptance 0.614
# t 87 | lam 0.75↔1.25 | integral -0.086 | acceptance 0.767
# t 86 | lam 0.25↔0.75 | integral 0.083 | acceptance 0.817
# t 86 | lam 1.25↔1.75 | integral -1.131 | acceptance 0.617
# t 85 | lam 0.75↔1.25 | integral -0.137 | acceptance 0.772
# t 84 | lam 0.25↔0.75 | integral 0.034 | acceptance 0.828
# t 84 | lam 1.25↔1.75 | integral -1.204 | acceptance 0.620
# t 83 | lam 0.75↔1.25 | integral -0.188 | acceptance 0.778
# t 82 | lam 0.25↔0.75 | integral -0.009 | acceptance 0.836
# t 82 | lam 1.25↔1.75 | integral -1.249 | acceptance 0.628
# t 81 | lam 0.75↔1.25 | integral -0.229 | acceptance 0.786
# t 80 | lam 0.25↔0.75 | integral -0.044 | acceptance 0.847
# t 80 | lam 1.25↔1.75 | integral -1.275 | acceptance 0.646
# t 79 | lam 0.75↔1.25 | integral -0.258 | acceptance 0.800
# t 78 | lam 0.25↔0.75 | integral -0.076 | acceptance 0.861
# t 78 | lam 1.25↔1.75 | integral -1.293 | acceptance 0.664
# t 77 | lam 0.75↔1.25 | integral -0.278 | acceptance 0.817
# t 76 | lam 0.25↔0.75 | integral -0.096 | acceptance 0.874
# t 76 | lam 1.25↔1.75 | integral -1.323 | acceptance 0.686
# t 75 | lam 0.75↔1.25 | integral -0.292 | acceptance 0.829
# t 74 | lam 0.25↔0.75 | integral -0.103 | acceptance 0.880
# t 74 | lam 1.25↔1.75 | integral -1.336 | acceptance 0.701
# t 73 | lam 0.75↔1.25 | integral -0.291 | acceptance 0.835
# t 72 | lam 0.25↔0.75 | integral -0.104 | acceptance 0.877
# t 72 | lam 1.25↔1.75 | integral -1.343 | acceptance 0.712
# t 71 | lam 0.75↔1.25 | integral -0.283 | acceptance 0.835
# t 70 | lam 0.25↔0.75 | integral -0.101 | acceptance 0.868
# t 70 | lam 1.25↔1.75 | integral -1.341 | acceptance 0.715
# t 69 | lam 0.75↔1.25 | integral -0.271 | acceptance 0.833
# t 68 | lam 0.25↔0.75 | integral -0.091 | acceptance 0.857
# t 68 | lam 1.25↔1.75 | integral -1.342 | acceptance 0.721
# t 67 | lam 0.75↔1.25 | integral -0.274 | acceptance 0.825
# t 66 | lam 0.25↔0.75 | integral -0.094 | acceptance 0.846
# t 66 | lam 1.25↔1.75 | integral -1.353 | acceptance 0.720
# t 65 | lam 0.75↔1.25 | integral -0.273 | acceptance 0.821
# t 64 | lam 0.25↔0.75 | integral -0.102 | acceptance 0.832
# t 64 | lam 1.25↔1.75 | integral -1.380 | acceptance 0.720
# t 63 | lam 0.75↔1.25 | integral -0.280 | acceptance 0.811
# t 62 | lam 0.25↔0.75 | integral -0.108 | acceptance 0.820
# t 62 | lam 1.25↔1.75 | integral -1.397 | acceptance 0.720
# t 61 | lam 0.75↔1.25 | integral -0.292 | acceptance 0.803
# t 60 | lam 0.25↔0.75 | integral -0.126 | acceptance 0.807
# t 60 | lam 1.25↔1.75 | integral -1.414 | acceptance 0.719
# t 59 | lam 0.75↔1.25 | integral -0.308 | acceptance 0.798
# t 58 | lam 0.25↔0.75 | integral -0.150 | acceptance 0.792
# t 58 | lam 1.25↔1.75 | integral -1.443 | acceptance 0.719
# t 57 | lam 0.75↔1.25 | integral -0.312 | acceptance 0.792
# t 56 | lam 0.25↔0.75 | integral -0.175 | acceptance 0.779
# t 56 | lam 1.25↔1.75 | integral -1.464 | acceptance 0.715
# t 55 | lam 0.75↔1.25 | integral -0.330 | acceptance 0.782
# t 54 | lam 0.25↔0.75 | integral -0.217 | acceptance 0.765
# t 54 | lam 1.25↔1.75 | integral -1.495 | acceptance 0.713
# t 53 | lam 0.75↔1.25 | integral -0.357 | acceptance 0.771
# t 52 | lam 0.25↔0.75 | integral -0.265 | acceptance 0.749
# t 52 | lam 1.25↔1.75 | integral -1.528 | acceptance 0.708
# t 51 | lam 0.75↔1.25 | integral -0.383 | acceptance 0.759
# t 50 | lam 0.25↔0.75 | integral -0.303 | acceptance 0.735
# t 50 | lam 1.25↔1.75 | integral -1.582 | acceptance 0.697
# t 49 | lam 0.75↔1.25 | integral -0.427 | acceptance 0.744
# t 48 | lam 0.25↔0.75 | integral -0.361 | acceptance 0.724
# t 48 | lam 1.25↔1.75 | integral -1.635 | acceptance 0.690
# t 47 | lam 0.75↔1.25 | integral -0.454 | acceptance 0.737
# t 46 | lam 0.25↔0.75 | integral -0.435 | acceptance 0.710
# t 46 | lam 1.25↔1.75 | integral -1.680 | acceptance 0.681
# t 45 | lam 0.75↔1.25 | integral -0.483 | acceptance 0.725
# t 44 | lam 0.25↔0.75 | integral -0.501 | acceptance 0.697
# t 44 | lam 1.25↔1.75 | integral -1.727 | acceptance 0.676
# t 43 | lam 0.75↔1.25 | integral -0.526 | acceptance 0.716
# t 42 | lam 0.25↔0.75 | integral -0.604 | acceptance 0.684
# t 42 | lam 1.25↔1.75 | integral -1.787 | acceptance 0.669
# t 41 | lam 0.75↔1.25 | integral -0.570 | acceptance 0.707
# t 40 | lam 0.25↔0.75 | integral -0.668 | acceptance 0.677
# t 40 | lam 1.25↔1.75 | integral -1.845 | acceptance 0.664
# t 39 | lam 0.75↔1.25 | integral -0.626 | acceptance 0.696
# t 38 | lam 0.25↔0.75 | integral -0.746 | acceptance 0.668
# t 38 | lam 1.25↔1.75 | integral -1.916 | acceptance 0.654
# t 37 | lam 0.75↔1.25 | integral -0.675 | acceptance 0.689
# t 36 | lam 0.25↔0.75 | integral -0.833 | acceptance 0.659
# t 36 | lam 1.25↔1.75 | integral -1.979 | acceptance 0.647
# t 35 | lam 0.75↔1.25 | integral -0.729 | acceptance 0.682
# t 34 | lam 0.25↔0.75 | integral -0.915 | acceptance 0.653
# t 34 | lam 1.25↔1.75 | integral -2.043 | acceptance 0.643
# t 33 | lam 0.75↔1.25 | integral -0.777 | acceptance 0.677
# t 32 | lam 0.25↔0.75 | integral -1.001 | acceptance 0.647
# t 32 | lam 1.25↔1.75 | integral -2.129 | acceptance 0.636
# t 31 | lam 0.75↔1.25 | integral -0.827 | acceptance 0.669
# t 30 | lam 0.25↔0.75 | integral -1.072 | acceptance 0.638
# t 30 | lam 1.25↔1.75 | integral -2.200 | acceptance 0.631
# t 29 | lam 0.75↔1.25 | integral -0.884 | acceptance 0.665
# t 28 | lam 0.25↔0.75 | integral -1.132 | acceptance 0.632
# t 28 | lam 1.25↔1.75 | integral -2.294 | acceptance 0.626
# t 27 | lam 0.75↔1.25 | integral -0.943 | acceptance 0.659
# t 26 | lam 0.25↔0.75 | integral -1.196 | acceptance 0.626
# t 26 | lam 1.25↔1.75 | integral -2.369 | acceptance 0.622
# t 25 | lam 0.75↔1.25 | integral -0.990 | acceptance 0.657
# t 24 | lam 0.25↔0.75 | integral -1.252 | acceptance 0.619
# t 24 | lam 1.25↔1.75 | integral -2.437 | acceptance 0.618
# t 23 | lam 0.75↔1.25 | integral -1.044 | acceptance 0.654
# t 22 | lam 0.25↔0.75 | integral -1.272 | acceptance 0.612
# t 22 | lam 1.25↔1.75 | integral -2.526 | acceptance 0.615
# t 21 | lam 0.75↔1.25 | integral -1.082 | acceptance 0.650
# t 20 | lam 0.25↔0.75 | integral -1.285 | acceptance 0.607
# t 20 | lam 1.25↔1.75 | integral -2.628 | acceptance 0.612
# t 19 | lam 0.75↔1.25 | integral -1.145 | acceptance 0.649
# t 18 | lam 0.25↔0.75 | integral -1.345 | acceptance 0.596
# t 18 | lam 1.25↔1.75 | integral -2.715 | acceptance 0.609
# t 17 | lam 0.75↔1.25 | integral -1.195 | acceptance 0.646
# t 16 | lam 0.25↔0.75 | integral -1.373 | acceptance 0.588
# t 16 | lam 1.25↔1.75 | integral -2.780 | acceptance 0.607
# t 15 | lam 0.75↔1.25 | integral -1.253 | acceptance 0.643
# t 14 | lam 0.25↔0.75 | integral -1.428 | acceptance 0.584
# t 14 | lam 1.25↔1.75 | integral -2.869 | acceptance 0.606
# t 13 | lam 0.75↔1.25 | integral -1.321 | acceptance 0.642
# t 12 | lam 0.25↔0.75 | integral -1.518 | acceptance 0.573
# t 12 | lam 1.25↔1.75 | integral -2.972 | acceptance 0.605
# t 11 | lam 0.75↔1.25 | integral -1.343 | acceptance 0.642
# t 10 | lam 0.25↔0.75 | integral -1.589 | acceptance 0.565
# t 10 | lam 1.25↔1.75 | integral -3.017 | acceptance 0.606
# t 9 | lam 0.75↔1.25 | integral -1.411 | acceptance 0.639
# t 8 | lam 0.25↔0.75 | integral -1.689 | acceptance 0.557
# t 8 | lam 1.25↔1.75 | integral -3.071 | acceptance 0.608
# t 7 | lam 0.75↔1.25 | integral -1.482 | acceptance 0.637
# t 6 | lam 0.25↔0.75 | integral -1.880 | acceptance 0.548
# t 6 | lam 1.25↔1.75 | integral -3.187 | acceptance 0.604
