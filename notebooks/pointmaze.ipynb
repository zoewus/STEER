# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.95 --lam_end 1.05 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.88 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.60 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.88 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.68 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.94 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.56 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.94 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.57 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.85 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.88 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.46 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.06 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.42 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.49 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.93 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.54 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.62 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -18.19 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -18.38 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.20 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.67 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.55 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -9.41 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -5.60 accept 0.00
# Best Sample: 5 log probability -0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/1/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.86 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.67 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.85 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.73 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.49 accept 0.01
# Time 187 1.04 and 1.05 log_ratio -3.69 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.68 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.03 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.78 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.39 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.57 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.58 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.38 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.24 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.78 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.67 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.35 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.52 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.49 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.88 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.25 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -20.85 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.67 accept 0.01
# Best Sample: 3 log probability -0.259
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/2/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.87 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.69 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.35 accept 0.04
# Time 187 0.97 and 0.99 log_ratio -3.82 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.89 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.12 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.59 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -14.99 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.91 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.98 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.64 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.09 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -14.29 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.62 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -36.63 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.40 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.76 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.26 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.71 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -20.48 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.34 accept 0.04
# Time 17 0.99 and 1.01 log_ratio -31.04 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -13.70 accept 0.00
# Best Sample: 5 log probability -0.028
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/3/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.51 accept 0.22
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.47 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.98 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.56 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -4.07 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.96 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.46 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.44 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.14 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.47 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.26 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.20 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.29 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.11 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.06 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.56 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.69 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.26 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -14.69 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.41 accept 0.03
# Time 17 0.99 and 1.01 log_ratio -14.97 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -7.09 accept 0.00
# Best Sample: 1 log probability -2.288
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/4/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/4/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.98 accept 0.38
# Time 221 0.99 and 1.01 log_ratio -1.71 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.72 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.89 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.98 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.72 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.92 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.48 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.54 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.05 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -15.31 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.02 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.10 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.82 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -39.17 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.77 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.75 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -24.41 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.15 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.51 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.52 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -37.84 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -12.59 accept 0.00
# Best Sample: 7 log probability -0.085
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/5/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/5/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.85 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -1.58 accept 0.21
# Time 221 1.02 and 1.04 log_ratio -0.90 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.87 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.79 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.70 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.88 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.39 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.66 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.92 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.52 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.91 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.05 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.19 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -18.02 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -29.71 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.54 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -18.20 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.48 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.81 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.49 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.56 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -9.87 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -6.53 accept 0.00
# Best Sample: 4 log probability -0.030
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/6/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/6/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.67 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.89 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.61 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.72 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.74 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.21 accept 0.01
# Time 153 0.96 and 0.97 log_ratio -7.96 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.76 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.87 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.89 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.91 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.20 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.71 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.74 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.43 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.89 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.77 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.21 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.19 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.22 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.87 accept 0.02
# Time 17 0.99 and 1.01 log_ratio 0.00 accept 1.00
# Time 17 1.02 and 1.04 log_ratio -6.23 accept 0.00
# Best Sample: 4 log probability -0.558
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/7/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/7/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.84 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -2.06 accept 0.13
# Time 221 1.02 and 1.04 log_ratio -0.89 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.61 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.03 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.87 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.95 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.65 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.41 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.90 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.76 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.24 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.93 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.19 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -14.56 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -30.59 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.25 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.39 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.36 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.75 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.50 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.82 accept 0.02
# Time 17 0.99 and 1.01 log_ratio -27.32 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.31 accept 0.00
# Best Sample: 1 log probability -0.421
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/8/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/8/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.78 accept 0.46
# Time 221 0.99 and 1.01 log_ratio -1.83 accept 0.16
# Time 221 1.02 and 1.04 log_ratio -0.79 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.85 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.68 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.52 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.75 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.60 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.11 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.71 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.72 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.29 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.45 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.90 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.57 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.85 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.03 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.02 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.19 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -20.66 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.17 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -0.80 accept 0.45
# Time 17 0.99 and 1.01 log_ratio -50.16 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -13.93 accept 0.00
# Best Sample: 0 log probability -0.133
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/9/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/9/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.59 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.83 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.67 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.73 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.50 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.72 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.81 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.98 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.76 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.92 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.54 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -15.60 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.18 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.84 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -38.02 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.48 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.88 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -22.43 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -25.31 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.48 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.80 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -13.37 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -16.02 accept 0.00
# Best Sample: 6 log probability -0.924
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/10/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/10/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.79 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.64 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.79 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.70 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.56 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.65 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.86 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.80 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.01 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.39 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.73 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.49 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.75 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.73 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.78 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.71 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.86 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.10 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.00 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.62 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.68 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -7.80 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -6.00 accept 0.00
# Best Sample: 5 log probability -0.040
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/11/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/11/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.52 accept 0.22
# Time 221 1.02 and 1.04 log_ratio -0.87 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.98 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.74 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.37 accept 0.01
# Time 187 1.04 and 1.05 log_ratio -3.70 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.19 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.32 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.95 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.41 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.48 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.08 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.17 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.61 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.53 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.40 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -18.46 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -18.67 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.87 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.52 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -10.66 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -16.83 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.06 accept 0.00
# Best Sample: 7 log probability -0.155
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/12/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/12/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.87 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.67 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.56 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.56 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.84 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.86 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.94 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.91 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.76 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.46 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.26 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.02 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.58 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.48 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -38.62 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.66 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.74 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -14.37 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -18.76 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.82 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.69 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -43.26 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.14 accept 0.02
# Best Sample: 5 log probability -0.014
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/13/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/13/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.74 accept 0.48
# Time 221 0.99 and 1.01 log_ratio -1.63 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.89 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.62 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.09 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.71 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.85 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.96 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.14 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.85 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.64 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.89 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.98 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.30 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -21.18 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -37.04 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.64 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -23.66 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.65 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -18.05 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.77 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -11.47 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -30.13 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -12.23 accept 0.00
# Best Sample: 0 log probability -0.074
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/14/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/14/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.66 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.50 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.87 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.57 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.79 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.32 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -14.76 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.01 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.95 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.45 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.45 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.09 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.95 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -30.29 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -18.97 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.73 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -13.97 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.34 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -20.42 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.72 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -16.11 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -24.78 accept 0.00
# Best Sample: 7 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/15/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/15/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.78 accept 0.46
# Time 221 0.99 and 1.01 log_ratio -1.64 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.66 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.79 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -6.39 accept 0.00
# Time 187 1.04 and 1.05 log_ratio -3.91 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.78 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.70 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.35 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.26 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.38 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.25 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.34 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.30 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -38.00 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.22 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.27 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.24 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -27.96 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.14 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.90 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -48.37 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -6.27 accept 0.00
# Best Sample: 1 log probability -0.396
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/16/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/16/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.80 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.97 accept 0.14
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.58 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.71 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.01 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.80 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.79 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.16 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.64 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.22 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.27 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.18 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.22 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.15 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.52 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.96 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.19 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -14.99 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.54 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.62 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -5.74 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -8.28 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -7.48 accept 0.00
# Best Sample: 3 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/17/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/17/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.93 accept 0.40
# Time 221 0.99 and 1.01 log_ratio -1.76 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -0.89 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -4.54 accept 0.01
# Time 187 0.97 and 0.99 log_ratio -3.67 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.62 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -4.48 accept 0.01
# Time 153 0.96 and 0.97 log_ratio -7.99 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -18.11 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.23 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.89 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.10 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.33 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.37 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -14.26 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.80 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.05 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.03 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.09 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -13.69 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.05 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -5.44 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -15.45 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -16.67 accept 0.00
# Best Sample: 5 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/18/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/18/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.84 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -1.66 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.88 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.51 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.95 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.59 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.80 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.29 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.97 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.93 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.22 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.80 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.82 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.20 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.48 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.76 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.52 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.92 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.25 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.04 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.96 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -9.72 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -11.28 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -12.31 accept 0.00
# Best Sample: 4 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/19/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/19/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.65 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.79 accept 0.46
# Time 187 0.95 and 0.96 log_ratio -3.76 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.71 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.54 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.72 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -9.28 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.58 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.98 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.94 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.75 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.29 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.68 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.16 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.73 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.98 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.19 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.56 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.75 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.56 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -2.39 accept 0.09
# Time 17 0.99 and 1.01 log_ratio -18.78 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -15.09 accept 0.00
# Best Sample: 4 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/20/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/20/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.93 accept 0.39
# Time 221 0.99 and 1.01 log_ratio -1.85 accept 0.16
# Time 221 1.02 and 1.04 log_ratio -0.87 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.48 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.81 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.26 accept 0.01
# Time 187 1.04 and 1.05 log_ratio -5.45 accept 0.00
# Time 153 0.96 and 0.97 log_ratio -7.68 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.46 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.56 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.22 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.89 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.19 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.20 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.06 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.98 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.21 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.13 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -14.84 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.37 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.58 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -2.35 accept 0.10
# Time 17 0.99 and 1.01 log_ratio -16.59 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -8.58 accept 0.00
# Best Sample: 6 log probability -4.328
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/21/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/21/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.97 accept 0.38
# Time 221 0.99 and 1.01 log_ratio -1.68 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.99 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.72 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.81 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.88 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.56 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -19.60 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.51 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.83 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.54 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.35 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -14.00 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.37 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.51 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -18.05 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -21.08 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -21.01 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.99 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -23.38 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -23.00 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -71.11 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -29.55 accept 0.00
# Best Sample: 5 log probability -0.447
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/22/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/22/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -1.12 accept 0.33
# Time 221 0.99 and 1.01 log_ratio -1.58 accept 0.21
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.51 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.10 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.08 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.96 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.38 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.79 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.49 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.15 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.62 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.80 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.91 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -21.38 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.68 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.25 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.75 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.19 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -20.81 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.85 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -9.00 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -15.95 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -14.59 accept 0.00
# Best Sample: 3 log probability -0.090
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/23/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/23/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.89 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.70 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.79 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.57 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.26 accept 0.01
# Time 187 1.01 and 1.02 log_ratio -3.68 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.73 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.85 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.50 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.63 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.31 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.17 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.12 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.66 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.89 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.77 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.90 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.75 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.80 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.23 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.98 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -2.59 accept 0.07
# Time 17 0.99 and 1.01 log_ratio -16.11 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -22.02 accept 0.00
# Best Sample: 1 log probability -0.013
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/24/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/24/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.88 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.71 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.66 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.79 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.85 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.61 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.99 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.62 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.05 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.44 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.88 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.61 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.40 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.60 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.00 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.27 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.31 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.83 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.27 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.09 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.51 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -29.16 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -14.00 accept 0.00
# Best Sample: 6 log probability -2.288
# ...
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.62 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.52 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.04 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.73 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.68 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.05 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.60 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.47 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.81 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.16 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.39 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.61 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.27 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -30.88 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.30 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.07 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -18.14 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.67 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -14.62 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -14.93 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -6.96 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -6.01 accept 0.00
# Best Sample: 7 log probability -0.072
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/34/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/34/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.88 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.71 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.89 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.86 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.81 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.67 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.53 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.96 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.26 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.96 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.51 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.52 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.22 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.30 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.15 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -36.38 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.35 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -21.48 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.92 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.24 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.35 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -8.97 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -28.36 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -3.12 accept 0.04
# Best Sample: 6 log probability -5.354
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/35/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/35/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.90 accept 0.40
# Time 221 0.99 and 1.01 log_ratio -1.71 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -4.43 accept 0.01
# Time 187 0.97 and 0.99 log_ratio -3.68 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.82 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.82 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.01 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.26 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.80 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.52 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.58 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.52 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.43 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -20.35 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -37.32 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.73 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -19.53 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.91 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -21.05 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -13.62 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -13.70 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -11.97 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -8.84 accept 0.00
# Best Sample: 6 log probability -1.432
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/36/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/36/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.57 accept 0.21
# Time 221 1.02 and 1.04 log_ratio -0.79 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.93 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.91 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.60 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.88 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.20 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.69 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.34 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.67 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.66 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.04 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.10 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.33 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.26 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.12 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -19.40 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.42 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.14 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.44 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.17 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -15.58 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -5.73 accept 0.00
# Best Sample: 2 log probability -0.010
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/37/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/37/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.92 accept 0.40
# Time 221 0.99 and 1.01 log_ratio -1.62 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.45 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.75 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.63 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.63 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.27 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.14 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.29 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.04 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.72 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.23 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.44 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.21 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.52 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.01 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.91 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.09 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.23 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.68 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.55 accept 0.03
# Time 17 0.99 and 1.01 log_ratio -7.09 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -8.11 accept 0.00
# Best Sample: 1 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/38/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/38/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.87 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.84 accept 0.16
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.56 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.75 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.53 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.85 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.68 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.00 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -11.23 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.13 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.29 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -14.12 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.27 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.25 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.11 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.49 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.81 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.26 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -20.48 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.49 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -2.57 accept 0.08
# Time 17 0.99 and 1.01 log_ratio -23.84 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -18.46 accept 0.00
# Best Sample: 6 log probability -1.095
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/39/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.69 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.47 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.47 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.83 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.03 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.09 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.56 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.85 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.30 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.24 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.13 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -14.17 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.17 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.91 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.55 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.12 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.63 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -24.82 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.58 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -11.95 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -25.44 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -18.56 accept 0.00
# Best Sample: 1 log probability -2.313
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 20:47:45/40/rollout.png
# Success Rate: 72.5, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x151b2a56cb80>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x151b359ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x151b359c73c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x151b34226680>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x151b359ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x151b359c73c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x151b2a56cb80>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x151b359ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x151b10805240>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x151b34226680>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x151b359ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x151b10805240>,
# 	),
# 	result = 0
# )
