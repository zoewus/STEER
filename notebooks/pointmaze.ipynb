# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.98 --lam_end 1.02 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# Time 255 i 0 lam_t 0.98000 lam_s 1.02041 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 255 i 0 lam_t 0.99000 lam_s 1.01010 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 255 i 0 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 238 i 1 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0001 accept 0.9999 swapped_frac 1.0000
# Time 238 i 1 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0001 accept 0.9999 swapped_frac 1.0000
# Time 238 i 1 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 221 i 2 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0006 accept 0.9994 swapped_frac 0.9992
# Time 221 i 2 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0003 accept 0.9997 swapped_frac 1.0000
# Time 221 i 2 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 204 i 3 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0013 accept 0.9987 swapped_frac 0.9979
# Time 204 i 3 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0007 accept 0.9993 swapped_frac 0.9988
# Time 204 i 3 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 187 i 4 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0021 accept 0.9979 swapped_frac 0.9971
# Time 187 i 4 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0009 accept 0.9991 swapped_frac 0.9996
# Time 187 i 4 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 170 i 5 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0031 accept 0.9969 swapped_frac 0.9950
# Time 170 i 5 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0016 accept 0.9984 swapped_frac 0.9979
# Time 170 i 5 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 153 i 6 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0045 accept 0.9956 swapped_frac 0.9942
# Time 153 i 6 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0024 accept 0.9976 swapped_frac 0.9983
# Time 153 i 6 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 136 i 7 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0053 accept 0.9948 swapped_frac 0.9958
# Time 136 i 7 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0029 accept 0.9971 swapped_frac 0.9963
# Time 136 i 7 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 119 i 8 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0072 accept 0.9929 swapped_frac 0.9933
# Time 119 i 8 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0031 accept 0.9969 swapped_frac 0.9971
# Time 119 i 8 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 102 i 9 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0077 accept 0.9924 swapped_frac 0.9925
# Time 102 i 9 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0055 accept 0.9946 swapped_frac 0.9979
# Time 102 i 9 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 85 i 10 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0127 accept 0.9877 swapped_frac 0.9904
# Time 85 i 10 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0058 accept 0.9943 swapped_frac 0.9979
# Time 85 i 10 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 68 i 11 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0119 accept 0.9885 swapped_frac 0.9875
# Time 68 i 11 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0070 accept 0.9931 swapped_frac 0.9904
# Time 68 i 11 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 51 i 12 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0148 accept 0.9857 swapped_frac 0.9867
# Time 51 i 12 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0058 accept 0.9943 swapped_frac 0.9929
# Time 51 i 12 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 34 i 13 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0146 accept 0.9860 swapped_frac 0.9858
# Time 34 i 13 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0139 accept 0.9866 swapped_frac 0.9842
# Time 34 i 13 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Time 17 i 14 lam_t 0.98000 lam_s 1.02041 log_ratio -0.0417 accept 0.9641 swapped_frac 0.9671
# Time 17 i 14 lam_t 0.99000 lam_s 1.01010 log_ratio -0.0130 accept 0.9877 swapped_frac 0.9900
# Time 17 i 14 lam_t 1.00000 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped_frac 1.0000
# Best Sample: 4 log probability -0.079
