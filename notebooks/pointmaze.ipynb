# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.98 --lam_end 1.02 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0027 accept 0.9973 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0301 accept 0.9704 swapped False
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0939 accept 0.9104 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0551 accept 0.9464 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0702 accept 0.9322 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0269 accept 0.9735 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0164 accept 0.9837 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1047 accept 0.9006 swapped False
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0482 accept 0.9529 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0224 accept 0.9778 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 2 log probability -0.013
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/1/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0581 accept 0.9435 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0569 accept 0.9447 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0249 accept 0.9754 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio -0.4897 accept 0.6128 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0528 accept 0.9486 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio -0.1757 accept 0.8389 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1509 accept 0.8599 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio -0.2632 accept 0.7686 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio -0.2803 accept 0.7555 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1779 accept 0.8370 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio -0.1860 accept 0.8303 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0979 accept 0.9067 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0558 accept 0.9457 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0973 accept 0.9073 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0892 accept 0.9147 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1161 accept 0.8904 swapped False
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability -0.581
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/2/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0209 accept 0.9793 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0180 accept 0.9821 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0043 accept 0.9957 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0165 accept 0.9837 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0205 accept 0.9797 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0059 accept 0.9941 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0061 accept 0.9939 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0116 accept 0.9885 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0862 accept 0.9174 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio -0.6408 accept 0.5269 swapped True
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 7 log probability -4.659
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/3/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0831 accept 0.9203 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0737 accept 0.9290 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio -0.
swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0336 accept 0.9669 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0478 accept 0.9533 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0073 accept 0.9928 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0244 accept 0.9759 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0286 accept 0.9718 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0253 accept 0.9750 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 7 log probability -0.117
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/37/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/37/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0250 accept 0.9753 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1074 accept 0.8982 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0201 accept 0.9801 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0010 accept 0.9990 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0631 accept 0.9389 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0753 accept 0.9274 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio -0.2302 accept 0.7943 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio -0.1647 accept 0.8481 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0165 accept 0.9837 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio -0.1422 accept 0.8675 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0016 accept 0.9984 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0839 accept 0.9195 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0077 accept 0.9924 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio -0.1189 accept 0.8879 swapped True
# Best Sample: 7 log probability -3.997
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/38/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/38/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0923 accept 0.9118 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0092 accept 0.9908 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0381 accept 0.9626 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0160 accept 0.9841 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio -0.0812 accept 0.9220 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0046 accept 0.9954 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0982 accept 0.9064 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0413 accept 0.9596 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0015 accept 0.9985 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0803 accept 0.9229 swapped True
# Best Sample: 5 log probability -0.072
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/39/rollout.png
# Time 255 i 0 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0512 accept 0.9501 swapped True
# Time 255 i 0 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0315 accept 0.9690 swapped True
# Time 255 i 0 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0215 accept 0.9787 swapped True
# Time 221 i 2 lam_t 0.98571 lam_s 0.99143 log_ratio -0.0152 accept 0.9849 swapped True
# Time 221 i 2 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0034 accept 0.9967 swapped True
# Time 187 i 4 lam_t 0.98000 lam_s 0.98571 log_ratio -0.0411 accept 0.9597 swapped True
# Time 187 i 4 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0190 accept 0.9811 swapped True
# Time 187 i 4 lam_t 1.00286 lam_s 1.00857 log_ratio -0.0403 accept 0.9605 swapped True
# Time 187 i 4 lam_t 1.01429 lam_s 1.02000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.98571 lam_s 0.99143 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00857 lam_s 1.01429 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.98000 lam_s 0.98571 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99143 lam_s 0.99714 log_ratio -0.0723 accept 0.9302 swapped True
# Time 119 i 8 lam_t 1.00286 lam_s 1.00857 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.01429 lam_s 1.02000 log_ratio -0.3016 accept 0.7396 swapped False
# Time 85 i 10 lam_t 0.98571 lam_s 0.99143 log_ratio -0.1158 accept 0.8906 swapped True
# Time 85 i 10 lam_t 0.99714 lam_s 1.00286 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00857 lam_s 1.01429 log_ratio -0.0135 accept 0.9866 swapped True
# Time 51 i 12 lam_t 0.98000 lam_s 0.98571 log_ratio -0.1084 accept 0.8973 swapped True
# Time 51 i 12 lam_t 0.99143 lam_s 0.99714 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00286 lam_s 1.00857 log_ratio -0.1638 accept 0.8489 swapped False
# Time 51 i 12 lam_t 1.01429 lam_s 1.02000 log_ratio -0.0023 accept 0.9977 swapped True
# Best Sample: 6 log probability -0.143
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-13 23:08:03/40/rollout.png
# Success Rate: 77.5, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14f0f80c0d30>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14f10353c4c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14f10351be40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14f101d8a830>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14f10353c4c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14f10351be40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14f0f80c0d30>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14f10353c4c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14f0ac0b1340>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14f101d8a830>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14f10353c4c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14f0ac0b1340>,
# 	),
# 	result = 0
# )
