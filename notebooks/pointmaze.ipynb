# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 1.00 --lam_end 1.25 --replica_exchange --n_particles 4 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# t 153 | lam 1.00↔1.08 | integral -0.019 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.053 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.033 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.070 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.077 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.003 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.022 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.086 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.016 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.030 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.185 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral 0.022 | acceptance 1.000
# t 17 | lam 1.00↔1.08 | integral -0.014 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.265 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.677 | acceptance 0.000
# Best Sample: 2 log probability -2.386
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/1/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.013 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.005 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.002 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.020 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.081 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.010 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral 0.046 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.049 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.044 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.005 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.173 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.049 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.006 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.321 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.796 | acceptance 0.000
# Best Sample: 1 log probability -0.991
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/2/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.075 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.024 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.043 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.000 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.001 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.106 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.005 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.018 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.120 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.025 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.066 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.065 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.049 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral 0.246 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -29.839 | acceptance 0.000
# Best Sample: 1 log probability -0.311
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/3/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.013 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.055 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.008 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.021 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.060 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.017 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.033 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.050 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.024 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.036 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.083 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.031 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.065 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.195 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.470 | acceptance 0.000
# Best Sample: 0 log probability -0.155
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/4/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/4/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.061 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.035 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.004 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.016 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.032 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.031 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.094 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.019 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.063 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.137 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.037 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.001 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.153 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.542 | acceptance 0.000
# Best Sample: 2 log probability -0.275
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/5/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/5/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.042 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.006 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.020 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.018 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.056 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.022 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.044 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.111 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.050 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.032 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.111 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.036 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.047 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.485 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral 0.612 | acceptance 1.000
# Best Sample: 0 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/6/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/6/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.005 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.051 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.018 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.035 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.041 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.008 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.038 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.020 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.007 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.021 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral 0.015 | acceptance 1.000
# t 34 | lam 1.08↔1.17 | integral -0.049 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.056 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.118 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.522 | acceptance 0.000
# Best Sample: 0 log probability -0.034
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/7/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/7/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.147 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.000 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.093 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.000 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.024 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.012 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.020 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.047 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.027 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.036 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.168 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.065 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.028 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.163 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.055 | acceptance 0.000
# Best Sample: 1 log probability -4.186
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/8/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/8/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.058 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.016 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.012 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.048 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.031 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.025 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.022 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.066 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.002 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.016 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.112 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.076 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.039 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral 0.145 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -25.841 | acceptance 0.000
# Best Sample: 1 log probability -48.487
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/9/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/9/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.157 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.006 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral 0.001 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.013 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.029 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.001 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.008 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.055 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.003 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.039 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.107 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.022 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.058 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.250 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral 0.066 | acceptance 1.000
# Best Sample: 1 log probability -2.160
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/10/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/10/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.050 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.009 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.010 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.016 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.041 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.080 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.020 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.083 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.106 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.008 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.077 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.082 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.019 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral 0.118 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -23.761 | acceptance 0.000
# Best Sample: 1 log probability -1.010
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/11/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/11/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.010 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.028 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.011 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.008 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.034 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.050 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.001 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.036 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.015 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.003 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral 0.108 | acceptance 1.000
# t 34 | lam 1.08↔1.17 | integral -0.101 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.125 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.141 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -9.927 | acceptance 0.000
# Best Sample: 3 log probability -14.407
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/12/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/12/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.020 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.001 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.024 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.001 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.025 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.020 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.078 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.026 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.022 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.137 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral 0.011 | acceptance 1.000
# t 17 | lam 1.00↔1.08 | integral 0.362 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.238 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -3.803 | acceptance 0.000
# Best Sample: 3 log probability -33.725
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/13/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/13/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.001 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.004 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.001 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral 0.014 | acceptance 1.000
# t 102 | lam 1.08↔1.17 | integral -0.023 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.009 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.069 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.025 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.017 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.081 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.002 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.142 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral 0.010 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -2.989 | acceptance 0.000
# Best Sample: 2 log probability -8.414
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/14/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/14/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.004 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.005 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.036 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.034 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.015 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.029 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.054 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.049 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.089 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.147 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.032 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral 0.180 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -1.377 | acceptance 0.000
# Best Sample: 1 log probability -0.299
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/15/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/15/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.035 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.023 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.019 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.010 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.074 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.017 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.028 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.061 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.044 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.011 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.079 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.097 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.047 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.357 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -2.178 | acceptance 0.000
# Best Sample: 0 log probability -0.168
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/16/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/16/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.024 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.031 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.042 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.023 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral 0.003 | acceptance 1.000
# t 102 | lam 1.08↔1.17 | integral -0.060 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.019 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.001 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.047 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.021 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.013 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.105 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.121 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.115 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -6.669 | acceptance 0.000
# Best Sample: 1 log probability -12.513
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/17/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/17/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.048 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.008 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.014 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.029 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.032 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.027 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.048 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.005 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.013 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.078 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.009 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.026 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.085 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.400 | acceptance 0.000
# Best Sample: 1 log probability -0.071
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/18/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/18/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.026 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.030 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.076 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.055 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.044 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.021 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.111 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.082 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.031 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.043 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.276 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.072 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.294 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -51.622 | acceptance 0.000
# Best Sample: 1 log probability -0.291
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/19/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/19/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.003 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.063 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.023 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.010 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.015 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.047 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.037 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.017 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.008 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.085 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.014 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.014 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.308 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.835 | acceptance 0.000
# Best Sample: 1 log probability -0.927
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/20/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/20/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.010 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.009 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral 0.067 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.032 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral 0.006 | acceptance 1.000
# t 102 | lam 1.08↔1.17 | integral -0.037 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.008 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.024 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.019 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.009 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.068 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.035 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.168 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -1.248 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.270 | acceptance 0.000
# Best Sample: 1 log probability -0.023
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/21/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/21/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.265 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.016 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.031 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.007 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.015 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.014 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.024 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.067 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.074 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.016 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.123 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.169 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.467 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.304 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -23.923 | acceptance 0.000
# Best Sample: 0 log probability -45.703
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/22/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/22/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.108 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.015 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral 0.009 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.049 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.031 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.017 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.073 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.012 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.038 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.089 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.009 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.039 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.026 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.166 | acceptance 0.000
# Best Sample: 0 log probability -0.050
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/23/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/23/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.010 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.019 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.032 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.033 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.060 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.019 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.010 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.101 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.019 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.005 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.117 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.032 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.039 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.048 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.993 | acceptance 0.000
# Best Sample: 1 log probability -5.117
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/24/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/24/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.016 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.002 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.029 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.340 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.056 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.034 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.004 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.051 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.068 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.018 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.110 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.214 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.053 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.138 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -25.401 | acceptance 0.000
# Best Sample: 1 log probability -0.529
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/25/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/25/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.021 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.004 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.015 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.002 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral 0.013 | acceptance 1.000
# t 102 | lam 1.08↔1.17 | integral -0.028 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.024 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral 0.004 | acceptance 1.000
# t 68 | lam 1.08↔1.17 | integral -0.063 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.003 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.017 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.014 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.102 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral 0.012 | acceptance 1.000
# t 0 | lam 1.08↔1.17 | integral -1.327 | acceptance 0.000
# Best Sample: 0 log probability -0.048
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/26/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/26/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.002 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.018 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.002 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.024 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.068 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.001 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.034 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.090 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.035 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.024 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.100 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.000 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.020 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.159 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral 0.430 | acceptance 1.000
# Best Sample: 0 log probability -0.475
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/27/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/27/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.207 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.055 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.148 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.004 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.055 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.017 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral 0.010 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.153 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.038 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.001 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.221 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.003 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.003 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.583 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.174 | acceptance 0.000
# Best Sample: 2 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/28/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/28/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.019 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.003 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.033 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.010 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.019 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.015 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.004 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.051 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.002 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.027 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.074 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.033 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.070 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.078 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.597 | acceptance 0.000
# Best Sample: 2 log probability -5.276
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/29/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/29/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.073 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.025 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.017 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.003 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.034 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.004 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral 0.023 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.058 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.031 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.028 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.085 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.083 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.037 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.244 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.635 | acceptance 0.000
# Best Sample: 2 log probability -15.743
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/30/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/30/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.007 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.047 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.033 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.004 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral 0.004 | acceptance 1.000
# t 102 | lam 1.08↔1.17 | integral -0.032 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.005 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.056 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.017 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.023 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.096 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.008 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.022 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.110 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.195 | acceptance 0.000
# Best Sample: 1 log probability -0.122
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/31/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/31/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.006 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.031 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.022 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.061 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.006 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.037 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.065 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.043 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.018 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.136 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.036 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.024 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.104 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.524 | acceptance 0.000
# Best Sample: 1 log probability -4.404
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/32/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/32/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.027 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.020 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.025 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.002 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.059 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.037 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.011 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.085 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.031 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.012 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.148 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.077 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.005 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.274 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -17.645 | acceptance 0.000
# Best Sample: 1 log probability -1.416
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/33/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/33/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.019 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.011 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.054 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.007 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.013 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.040 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.016 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.026 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.045 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.013 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.160 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.004 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral -0.010 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.154 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.523 | acceptance 0.000
# Best Sample: 0 log probability -0.066
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/34/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/34/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.014 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.035 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral 0.009 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.113 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.063 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.008 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral 0.016 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.126 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.007 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral -0.033 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.082 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral 0.010 | acceptance 1.000
# t 17 | lam 1.00↔1.08 | integral -0.038 | acceptance 0.000
# t 17 | lam 1.17↔1.25 | integral -0.275 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.206 | acceptance 0.000
# Best Sample: 2 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/35/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/35/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.018 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral 0.010 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral 0.020 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.008 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.024 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.007 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral -0.021 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.053 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral 0.016 | acceptance 1.000
# t 51 | lam 1.00↔1.08 | integral -0.052 | acceptance 0.000
# t 51 | lam 1.17↔1.25 | integral -0.108 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.050 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.073 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.025 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.990 | acceptance 0.000
# Best Sample: 3 log probability -4.058
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/36/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/36/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.004 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.021 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral -0.001 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral 0.012 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.060 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.031 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.006 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.088 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.006 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.095 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.177 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.057 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.002 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.015 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.320 | acceptance 0.000
# Best Sample: 2 log probability -1.552
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/37/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/37/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.042 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral 0.030 | acceptance 1.000
# t 136 | lam 1.08↔1.17 | integral -0.021 | acceptance 0.000
# t 119 | lam 1.00↔1.08 | integral -0.012 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.023 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.009 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.016 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.049 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.030 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.018 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.066 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.018 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.040 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.017 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -1.790 | acceptance 0.000
# Best Sample: 2 log probability -2.468
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/38/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/38/rollout.png
# t 153 | lam 1.00↔1.08 | integral -0.020 | acceptance 0.000
# t 153 | lam 1.17↔1.25 | integral -0.030 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.040 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral -0.023 | acceptance 0.000
# t 119 | lam 1.17↔1.25 | integral -0.136 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral 0.021 | acceptance 1.000
# t 85 | lam 1.00↔1.08 | integral -0.026 | acceptance 0.000
# t 85 | lam 1.17↔1.25 | integral -0.102 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.040 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.023 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.119 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.011 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.089 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.350 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral -0.572 | acceptance 0.000
# Best Sample: 2 log probability -2.067
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/39/rollout.png
# t 153 | lam 1.00↔1.08 | integral 0.014 | acceptance 1.000
# t 153 | lam 1.17↔1.25 | integral -0.021 | acceptance 0.000
# t 136 | lam 1.08↔1.17 | integral 0.084 | acceptance 1.000
# t 119 | lam 1.00↔1.08 | integral 0.041 | acceptance 1.000
# t 119 | lam 1.17↔1.25 | integral -0.068 | acceptance 0.000
# t 102 | lam 1.08↔1.17 | integral -0.032 | acceptance 0.000
# t 85 | lam 1.00↔1.08 | integral 0.007 | acceptance 1.000
# t 85 | lam 1.17↔1.25 | integral -0.101 | acceptance 0.000
# t 68 | lam 1.08↔1.17 | integral -0.019 | acceptance 0.000
# t 51 | lam 1.00↔1.08 | integral 0.038 | acceptance 1.000
# t 51 | lam 1.17↔1.25 | integral -0.177 | acceptance 0.000
# t 34 | lam 1.08↔1.17 | integral -0.013 | acceptance 0.000
# t 17 | lam 1.00↔1.08 | integral 0.074 | acceptance 1.000
# t 17 | lam 1.17↔1.25 | integral -0.571 | acceptance 0.000
# t 0 | lam 1.08↔1.17 | integral 1.348 | acceptance 1.000
# Best Sample: 0 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-08 21:59:39/40/rollout.png
# Success Rate: 52.5, Average Compute: 128.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x145716dccaf0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1457222448c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x145722225f40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x145720a865f0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1457222448c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x145722225f40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x145716dccaf0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1457222448c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1456beae5140>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x145720a865f0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1457222448c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1456beae5140>,
# 	),
# 	result = 0
# )
