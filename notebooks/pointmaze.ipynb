# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.99 --lam_end 1.01 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# i=0 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=-0.047457 integral_std=1.971747 log_ratio=-113.8963 accept=0.0000 swapped=False
# i=0 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=-0.018061 integral_std=2.012885 log_ratio=-43.3463 accept=0.0000 swapped=False
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=-0.054117 integral_std=1.960083 log_ratio=-129.8806 accept=0.0000 swapped=False
# i=0 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=0.056400 integral_std=2.131312 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=-0.008001 integral_std=2.096470 log_ratio=-19.2015 accept=0.0000 swapped=False
# i=0 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=-0.049910 integral_std=2.042096 log_ratio=-119.7830 accept=0.0000 swapped=False
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=0.030899 integral_std=1.994652 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=-0.023157 integral_std=2.102311 log_ratio=-55.5768 accept=0.0000 swapped=False
# i=1 pair=(1,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=0.039535 integral_std=1.995181 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(3,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=0.037984 integral_std=1.979615 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=-0.025591 integral_std=2.023405 log_ratio=-61.4175 accept=0.0000 swapped=False
# i=1 pair=(2,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=-0.003430 integral_std=2.057876 log_ratio=-8.2328 accept=0.0003 swapped=False
# i=1 pair=(5,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=-0.019972 integral_std=1.977975 log_ratio=-47.9335 accept=0.0000 swapped=False
# i=1 pair=(4,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=-0.026696 integral_std=2.059583 log_ratio=-64.0716 accept=0.0000 swapped=False
# i=2 pair=(0,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=0.010730 integral_std=2.115858 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=0.070942 integral_std=2.102386 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(3,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=0.051667 integral_std=2.191111 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=-0.155302 integral_std=2.021900 log_ratio=-372.7260 accept=0.0000 swapped=False
# i=2 pair=(2,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=-0.087477 integral_std=2.089225 log_ratio=-209.9437 accept=0.0000 swapped=False
# i=2 pair=(5,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=-0.045502 integral_std=2.052156 log_ratio=-109.2049 accept=0.0000 swapped=False
# i=2 pair=(4,3) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=-0.113414 integral_std=2.092164 log_ratio=-272.1935 accept=0.0000 swapped=False
# i=2 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=-0.054681 integral_std=1.968649 log_ratio=-131.2339 accept=0.0000 swapped=False
# i=3 pair=(0,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=0.040967 integral_std=2.181140 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(1,4) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=0.106946 integral_std=2.033661 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(3,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=-0.064769 integral_std=2.250675 log_ratio=-155.4459 accept=0.0000 swapped=False
# i=3 pair=(5,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=-0.046340 integral_std=2.032104 log_ratio=-111.2156 accept=0.0000 swapped=False
# i=3 pair=(4,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=-0.026467 integral_std=2.114859 log_ratio=-63.5211 accept=0.0000 swapped=False
# i=3 pair=(3,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=-0.018256 integral_std=2.107351 log_ratio=-43.8154 accept=0.0000 swapped=False
# i=4 pair=(2,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=0.257062 integral_std=2.316240 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(0,4) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=-0.276122 integral_std=2.535592 log_ratio=-662.6932 accept=0.0000 swapped=False
# i=4 pair=(1,3) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.017225 integral_std=2.126169 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=0.000146 integral_std=2.088808 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(5,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=-0.209369 integral_std=2.334610 log_ratio=-502.4845 accept=0.0000 swapped=False
# i=4 pair=(0,4) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=-0.195517 integral_std=2.136705 log_ratio=-469.2397 accept=0.0000 swapped=False
# i=4 pair=(3,1) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.040253 integral_std=2.198154 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=0.005520 integral_std=2.105994 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(2,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=0.185499 integral_std=2.327021 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(4,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=0.100912 integral_std=2.230642 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.118208 integral_std=2.190641 log_ratio=-283.7003 accept=0.0000 swapped=False
# i=5 pair=(0,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=-0.062264 integral_std=2.219784 log_ratio=-149.4328 accept=0.0000 swapped=False
# i=5 pair=(1,4) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=-0.117560 integral_std=2.174117 log_ratio=-282.1450 accept=0.0000 swapped=False
# i=5 pair=(3,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.005825 integral_std=2.118303 log_ratio=-13.9808 accept=0.0000 swapped=False
# i=6 pair=(5,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=0.063621 integral_std=2.205133 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(2,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=0.068477 integral_std=2.312320 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(4,3) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=0.072159 integral_std=2.223604 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.044322 integral_std=2.200654 log_ratio=-106.3721 accept=0.0000 swapped=False
# i=6 pair=(0,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.059080 integral_std=2.153902 log_ratio=-141.7910 accept=0.0000 swapped=False
# i=6 pair=(1,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=-0.015572 integral_std=2.311311 log_ratio=-37.3737 accept=0.0000 swapped=False
# i=6 pair=(3,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=-0.659285 integral_std=3.321808 log_ratio=-1582.2842 accept=0.0000 swapped=False
# i=6 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.098337 integral_std=2.243057 log_ratio=-236.0080 accept=0.0000 swapped=False
# i=7 pair=(5,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=0.037178 integral_std=2.161535 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(2,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=-0.042222 integral_std=2.219693 log_ratio=-101.3331 accept=0.0000 swapped=False
# i=7 pair=(4,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=0.344874 integral_std=3.443133 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(1,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=-0.084858 integral_std=2.201530 log_ratio=-203.6595 accept=0.0000 swapped=False
# i=7 pair=(2,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=-0.022161 integral_std=2.207651 log_ratio=-53.1854 accept=0.0000 swapped=False
# i=7 pair=(7,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=-0.245218 integral_std=2.987066 log_ratio=-588.5220 accept=0.0000 swapped=False
# i=8 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=0.002745 integral_std=2.252715 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(5,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=0.011330 integral_std=2.175628 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.123401 integral_std=2.425097 log_ratio=-296.1612 accept=0.0000 swapped=False
# i=8 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=0.296042 integral_std=2.663870 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.159947 integral_std=2.236648 log_ratio=-383.8733 accept=0.0000 swapped=False
# i=8 pair=(2,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=-0.012333 integral_std=2.257333 log_ratio=-29.6001 accept=0.0000 swapped=False
# i=8 pair=(3,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.225514 integral_std=2.678131 log_ratio=-541.2341 accept=0.0000 swapped=False
# i=8 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.004454 integral_std=2.453328 log_ratio=-10.6907 accept=0.0000 swapped=False
# i=9 pair=(0,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=0.141728 integral_std=2.917505 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(5,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=0.003252 integral_std=2.391881 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(7,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=0.135857 integral_std=2.748621 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(2,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.132769 integral_std=2.823136 log_ratio=-318.6446 accept=0.0000 swapped=False
# i=9 pair=(3,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=-0.053401 integral_std=2.361510 log_ratio=-128.1630 accept=0.0000 swapped=False
# i=9 pair=(6,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=0.014409 integral_std=2.771128 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.142668 integral_std=2.919947 log_ratio=-342.4032 accept=0.0000 swapped=False
# i=10 pair=(0,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=0.170464 integral_std=2.897098 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=0.041022 integral_std=2.858842 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=0.090229 integral_std=3.468131 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.152477 integral_std=3.019953 log_ratio=-365.9458 accept=0.0000 swapped=False
# i=10 pair=(3,0) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=-0.469632 integral_std=3.497205 log_ratio=-1127.1176 accept=0.0000 swapped=False
# i=10 pair=(7,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=0.006935 integral_std=2.727201 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=-0.003905 integral_std=3.063117 log_ratio=-9.3727 accept=0.0001 swapped=False
# i=11 pair=(2,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=0.008891 integral_std=3.376320 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(0,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=0.232616 integral_std=3.692474 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(7,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=-0.072432 integral_std=3.390150 log_ratio=-173.8377 accept=0.0000 swapped=False
# i=11 pair=(3,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=0.069948 integral_std=3.296019 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(5,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=-0.095263 integral_std=3.524657 log_ratio=-228.6320 accept=0.0000 swapped=False
# i=11 pair=(7,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=-0.031384 integral_std=3.232586 log_ratio=-75.3212 accept=0.0000 swapped=False
# i=12 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=-0.144476 integral_std=4.606515 log_ratio=-346.7431 accept=0.0000 swapped=False
# i=12 pair=(3,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=-0.062600 integral_std=4.586910 log_ratio=-150.2405 accept=0.0000 swapped=False
# i=12 pair=(0,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=0.351416 integral_std=4.076159 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=-0.131254 integral_std=4.262338 log_ratio=-315.0107 accept=0.0000 swapped=False
# i=12 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=-0.212552 integral_std=4.487977 log_ratio=-510.1244 accept=0.0000 swapped=False
# i=12 pair=(3,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=0.001814 integral_std=3.755663 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(7,0) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=-0.173927 integral_std=3.854865 log_ratio=-417.4236 accept=0.0000 swapped=False
# i=12 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=-0.269607 integral_std=4.398253 log_ratio=-647.0573 accept=0.0000 swapped=False
# i=13 pair=(2,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=-0.115979 integral_std=7.176197 log_ratio=-278.3502 accept=0.0000 swapped=False
# i=13 pair=(3,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=0.033871 integral_std=5.609913 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(0,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=0.186032 integral_std=7.463581 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(2,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=-0.126048 integral_std=5.935397 log_ratio=-302.5157 accept=0.0000 swapped=False
# i=13 pair=(7,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=0.132446 integral_std=4.183708 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(4,0) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=-0.221863 integral_std=5.920856 log_ratio=-532.4717 accept=0.0000 swapped=False
# i=14 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.634018 integral_std=11.513514 log_ratio=-1521.6443 accept=0.0000 swapped=False
# i=14 pair=(5,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=0.572513 integral_std=12.404202 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(7,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=-0.049960 integral_std=11.033234 log_ratio=-119.9041 accept=0.0000 swapped=False
# i=14 pair=(0,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=0.060729 integral_std=12.143144 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.500511 integral_std=10.173123 log_ratio=-1201.2253 accept=0.0000 swapped=False
# i=14 pair=(3,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=-0.691489 integral_std=9.050755 log_ratio=-1659.5726 accept=0.0000 swapped=False
# i=14 pair=(7,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=-0.242129 integral_std=8.270360 log_ratio=-581.1086 accept=0.0000 swapped=False
# i=14 pair=(6,0) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=-0.561965 integral_std=11.120103 log_ratio=-1348.7164 accept=0.0000 swapped=False
# Best Sample: 1 log probability -0.133
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/1/rollout.png
# i=0 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=0.015098 integral_std=2.050499 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=0.083466 integral_std=2.004712 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=-0.102845 integral_std=1.984778 log_ratio=-246.8289 accept=0.0000 swapped=False
# i=0 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=-0.041251 integral_std=1.942789 log_ratio=-99.0021 accept=0.0000 swapped=False
# i=0 pair=(1,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=0.046326 integral_std=1.927298 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(3,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=-0.032916 integral_std=1.989182 log_ratio=-78.9985 accept=0.0000 swapped=False
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=-0.034929 integral_std=1.969105 log_ratio=-83.8299 accept=0.0000 swapped=False
# i=0 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=-0.037125 integral_std=1.978346 log_ratio=-89.0993 accept=0.0000 swapped=False
# i=1 pair=(1,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=-0.041420 integral_std=1.953551 log_ratio=-99.4087 accept=0.0000 swapped=False
# i=1 pair=(2,4) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=0.055391 integral_std=1.966295 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(5,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=-0.025289 integral_std=1.992828 log_ratio=-60.6933 accept=0.0000 swapped=False
# i=1 pair=(1,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=-0.003084 integral_std=1.953931 log_ratio=-7.4021 accept=0.0006 swapped=False
# i=1 pair=(4,2) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=-0.008646 integral_std=1.989443 log_ratio=-20.7511 accept=0.0000 swapped=False
# i=1 pair=(5,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=0.014498 integral_std=2.113246 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=-0.066381 integral_std=1.940897 log_ratio=-159.3151 accept=0.0000 swapped=False
# i=2 pair=(3,4) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=0.004927 integral_std=1.966508 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(2,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=-0.015828 integral_std=2.145876 log_ratio=-37.9863 accept=0.0000 swapped=False
# i=2 pair=(5,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=0.221315 integral_std=2.189607 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=0.018299 integral_std=1.906612 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(4,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=0.083403 integral_std=2.090951 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(2,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=0.086031 integral_std=2.007941 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(7,5) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=-0.563988 integral_std=2.649047 log_ratio=-1353.5714 accept=0.0000 swapped=False
# i=3 pair=(0,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=-0.000336 integral_std=2.022947 log_ratio=-0.8056 accept=0.4468 swapped=True
# i=3 pair=(4,6) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=0.099570 integral_std=2.134381 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(2,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=0.091339 integral_std=1.995126 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(3,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=-0.026466 integral_std=2.081794 log_ratio=-63.5173 accept=0.0000 swapped=False
# i=3 pair=(6,4) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=-0.071493 integral_std=2.039518 log_ratio=-171.5837 accept=0.0000 swapped=False
# i=3 pair=(7,2) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=-0.465844 integral_std=2.561256 log_ratio=-1118.0245 accept=0.0000 swapped=False
# i=4 pair=(1,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=-0.058399 integral_std=1.910810 log_ratio=-140.1583 accept=0.0000 swapped=False
# i=4 pair=(0,6) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=0.041083 integral_std=2.168247 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(4,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.042415 integral_std=2.075202 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(2,5) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=0.180952 integral_std=2.753582 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(1,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=-0.075423 integral_std=1.939808 log_ratio=-181.0158 accept=0.0000 swapped=False
# i=4 pair=(6,0) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=-0.094847 integral_std=2.202150 log_ratio=-227.6329 accept=0.0000 swapped=False
# i=4 pair=(7,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=-0.035053 integral_std=2.208219 log_ratio=-84.1272 accept=0.0000 swapped=False
# i=4 pair=(5,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=-0.010565 integral_std=2.438255 log_ratio=-25.3555 accept=0.0000 swapped=False
# i=5 pair=(3,6) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=0.038609 integral_std=2.090125 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(0,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=0.037004 integral_std=2.054975 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(4,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.100908 integral_std=2.193401 log_ratio=-242.1788 accept=0.0000 swapped=False
# i=5 pair=(6,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=-0.009859 integral_std=2.062873 log_ratio=-23.6612 accept=0.0000 swapped=False
# i=5 pair=(7,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=-0.068225 integral_std=1.942677 log_ratio=-163.7404 accept=0.0000 swapped=False
# i=5 pair=(4,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.167631 integral_std=2.224345 log_ratio=-402.3145 accept=0.0000 swapped=False
# i=6 pair=(1,6) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.008910 integral_std=2.038168 log_ratio=-21.3835 accept=0.0000 swapped=False
# i=6 pair=(3,7) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=0.040166 integral_std=1.980474 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(0,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=-0.180481 integral_std=2.351128 log_ratio=-433.1553 accept=0.0000 swapped=False
# i=6 pair=(5,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=0.175246 integral_std=2.484700 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(1,6) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.000175 integral_std=2.021657 log_ratio=-0.4196 accept=0.6573 swapped=True
# i=6 pair=(7,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=0.058226 integral_std=1.973017 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(0,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=-0.102474 integral_std=2.270907 log_ratio=-245.9371 accept=0.0000 swapped=False
# i=6 pair=(2,5) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.029858 integral_std=2.213626 log_ratio=-71.6595 accept=0.0000 swapped=False
# i=7 pair=(1,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=0.068573 integral_std=2.038060 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(7,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=0.043295 integral_std=2.140063 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(4,2) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=-0.027469 integral_std=2.330250 log_ratio=-65.9247 accept=0.0000 swapped=False
# i=7 pair=(3,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=-0.039911 integral_std=2.017408 log_ratio=-95.7873 accept=0.0000 swapped=False
# i=7 pair=(0,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=0.012735 integral_std=2.101371 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(4,2) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=-0.079172 integral_std=2.241857 log_ratio=-190.0124 accept=0.0000 swapped=False
# i=8 pair=(6,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.035509 integral_std=1.899056 log_ratio=-85.2216 accept=0.0000 swapped=False
# i=8 pair=(1,7) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=-0.000969 integral_std=2.064764 log_ratio=-2.3260 accept=0.0977 swapped=False
# i=8 pair=(0,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.064637 integral_std=2.295544 log_ratio=-155.1291 accept=0.0000 swapped=False
# i=8 pair=(2,5) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=0.077854 integral_std=2.371257 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(6,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=0.009923 integral_std=1.945576 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,7) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=-0.013149 integral_std=2.093328 log_ratio=-31.5588 accept=0.0000 swapped=False
# i=8 pair=(0,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.061746 integral_std=2.496747 log_ratio=-148.1913 accept=0.0000 swapped=False
# i=8 pair=(5,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.118491 integral_std=2.420650 log_ratio=-284.3795 accept=0.0000 swapped=False
# i=9 pair=(6,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.043171 integral_std=2.103513 log_ratio=-103.6098 accept=0.0000 swapped=False
# i=9 pair=(7,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=-0.042249 integral_std=2.332518 log_ratio=-101.3971 accept=0.0000 swapped=False
# i=9 pair=(4,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=-0.035666 integral_std=2.319588 log_ratio=-85.5990 accept=0.0000 swapped=False
# i=9 pair=(6,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.005174 integral_std=2.091673 log_ratio=-12.4182 accept=0.0000 swapped=False
# i=9 pair=(7,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=-0.057601 integral_std=2.282352 log_ratio=-138.2421 accept=0.0000 swapped=False
# i=9 pair=(4,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=-0.052568 integral_std=2.193268 log_ratio=-126.1628 accept=0.0000 swapped=False
# i=10 pair=(3,6) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.016329 integral_std=2.031018 log_ratio=-39.1901 accept=0.0000 swapped=False
# i=10 pair=(1,7) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=0.003619 integral_std=2.071927 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(0,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=0.091007 integral_std=2.666833 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=-0.351689 integral_std=3.215571 log_ratio=-844.0529 accept=0.0000 swapped=False
# i=10 pair=(3,6) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.011231 integral_std=2.027492 log_ratio=-26.9547 accept=0.0000 swapped=False
# i=10 pair=(7,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=-0.006166 integral_std=1.962869 log_ratio=-14.7980 accept=0.0000 swapped=False
# i=10 pair=(4,0) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=-0.084986 integral_std=2.889009 log_ratio=-203.9665 accept=0.0000 swapped=False
# i=10 pair=(5,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=-0.262112 integral_std=2.876804 log_ratio=-629.0684 accept=0.0000 swapped=False
# i=11 pair=(6,7) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=0.052745 integral_std=2.044585 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,4) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=0.016934 integral_std=2.671009 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(0,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=-0.001791 integral_std=3.236407 log_ratio=-4.2990 accept=0.0136 swapped=False
# i=11 pair=(7,6) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=-0.004425 integral_std=2.030375 log_ratio=-10.6192 accept=0.0000 swapped=False
# i=11 pair=(4,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=-0.048446 integral_std=2.482049 log_ratio=-116.2712 accept=0.0000 swapped=False
# i=11 pair=(0,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=0.134854 integral_std=3.284765 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(3,7) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=0.002039 integral_std=2.129833 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(6,4) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=0.052669 integral_std=2.947670 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=-0.096457 integral_std=3.400511 log_ratio=-231.4966 accept=0.0000 swapped=False
# i=12 pair=(0,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=-0.450290 integral_std=5.225138 log_ratio=-1080.6957 accept=0.0000 swapped=False
# i=12 pair=(7,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=0.007512 integral_std=2.044050 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(4,6) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=-0.019713 integral_std=3.167587 log_ratio=-47.3123 accept=0.0000 swapped=False
# i=12 pair=(1,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=-0.107799 integral_std=3.067536 log_ratio=-258.7172 accept=0.0000 swapped=False
# i=12 pair=(0,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=-0.380042 integral_std=5.422637 log_ratio=-912.0997 accept=0.0000 swapped=False
# i=13 pair=(7,4) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=0.040680 integral_std=3.849348 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(6,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=0.023384 integral_std=2.144807 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(5,0) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=-0.260372 integral_std=5.808288 log_ratio=-624.8934 accept=0.0000 swapped=False
# i=13 pair=(4,7) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=-0.059526 integral_std=3.739615 log_ratio=-142.8627 accept=0.0000 swapped=False
# i=13 pair=(1,6) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=-0.074118 integral_std=2.164990 log_ratio=-177.8822 accept=0.0000 swapped=False
# i=13 pair=(5,0) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=-0.385940 integral_std=6.583598 log_ratio=-926.2557 accept=0.0000 swapped=False
# i=14 pair=(3,4) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.137088 integral_std=6.681283 log_ratio=-329.0120 accept=0.0000 swapped=False
# i=14 pair=(7,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=-0.039931 integral_std=2.630438 log_ratio=-95.8351 accept=0.0000 swapped=False
# i=14 pair=(6,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=-0.421257 integral_std=6.861138 log_ratio=-1011.0173 accept=0.0000 swapped=False
# i=14 pair=(0,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=-1.660612 integral_std=21.558617 log_ratio=-3985.4695 accept=0.0000 swapped=False
# i=14 pair=(3,4) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.215360 integral_std=6.475805 log_ratio=-516.8633 accept=0.0000 swapped=False
# i=14 pair=(7,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=0.102110 integral_std=2.771454 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(6,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=-0.535582 integral_std=6.583585 log_ratio=-1285.3967 accept=0.0000 swapped=False
# i=14 pair=(0,2) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=1.425249 integral_std=38.716583 log_ratio=0.0000 accept=1.0000 swapped=True
# Best Sample: 6 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/2/rollout.png
# i=0 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=-0.008392 integral_std=2.043191 log_ratio=-20.1410 accept=0.0000 swapped=False
# i=0 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=-0.111481 integral_std=2.050984 log_ratio=-267.5535 accept=0.0000 swapped=False
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=-0.040762 integral_std=2.033542 log_ratio=-97.8292 accept=0.0000 swapped=False
# i=0 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=-0.010158 integral_std=1.998149 log_ratio=-24.3794 accept=0.0000 swapped=False
# i=0 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000000 integral_mean=0.014866 integral_std=1.922882 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=1.000000 integral_mean=-0.089729 integral_std=2.102152 log_ratio=-215.3484 accept=0.0000 swapped=False
# i=0 pair=(4,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=1.000000 integral_mean=0.059869 integral_std=2.022286 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=1.000000 integral_mean=-0.035885 integral_std=2.001680 log_ratio=-86.1242 accept=0.0000 swapped=False
# i=1 pair=(0,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=-0.009952 integral_std=1.937659 log_ratio=-23.8853 accept=0.0000 swapped=False
# i=1 pair=(3,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=0.002603 integral_std=1.966474 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=0.031894 integral_std=1.982519 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999973 integral_mean=-0.038640 integral_std=2.002369 log_ratio=-92.7365 accept=0.0000 swapped=False
# i=1 pair=(5,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999904 integral_mean=-0.023130 integral_std=1.942482 log_ratio=-55.5124 accept=0.0000 swapped=False
# i=1 pair=(6,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999895 integral_mean=0.011618 integral_std=1.979730 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=-0.106128 integral_std=2.225032 log_ratio=-254.7061 accept=0.0000 swapped=False
# i=2 pair=(2,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=-0.012852 integral_std=2.066168 log_ratio=-30.8446 accept=0.0000 swapped=False
# i=2 pair=(3,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=-0.031492 integral_std=1.978716 log_ratio=-75.5797 accept=0.0000 swapped=False
# i=2 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=-0.093093 integral_std=1.976986 log_ratio=-223.4231 accept=0.0000 swapped=False
# i=2 pair=(1,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.000422 integral_mean=-0.090013 integral_std=2.061517 log_ratio=-216.0319 accept=0.0000 swapped=False
# i=2 pair=(2,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.999695 integral_mean=0.064209 integral_std=1.998084 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(3,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.999594 integral_mean=-0.060727 integral_std=1.942632 log_ratio=-145.7456 accept=0.0000 swapped=False
# i=2 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.999580 integral_mean=-0.044614 integral_std=2.095723 log_ratio=-107.0732 accept=0.0000 swapped=False
# i=3 pair=(0,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=0.027822 integral_std=2.132953 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(2,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=0.043629 integral_std=2.132470 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(4,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=-0.044155 integral_std=2.045811 log_ratio=-105.9716 accept=0.0000 swapped=False
# i=3 pair=(5,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999762 integral_mean=-0.012938 integral_std=2.119087 log_ratio=-31.0515 accept=0.0000 swapped=False
# i=3 pair=(3,2) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.999164 integral_mean=-0.021193 integral_std=2.018506 log_ratio=-50.8640 accept=0.0000 swapped=False
# i=3 pair=(4,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.999081 integral_mean=-0.109129 integral_std=2.103415 log_ratio=-261.9096 accept=0.0000 swapped=False
# i=4 pair=(1,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=0.005830 integral_std=2.135716 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(0,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=-0.027327 integral_std=2.108629 log_ratio=-65.5841 accept=0.0000 swapped=False
# i=4 pair=(2,4) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.005682 integral_std=2.080581 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(6,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=0.032360 integral_std=2.195112 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(5,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=0.050263 integral_std=2.121265 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(0,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=-0.022846 integral_std=2.065414 log_ratio=-54.8299 accept=0.0000 swapped=False
# i=4 pair=(4,2) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.024972 integral_std=1.949275 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(7,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=-0.029654 integral_std=2.171545 log_ratio=-71.1704 accept=0.0000 swapped=False
# i=5 pair=(5,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=0.048939 integral_std=2.288947 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,2) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=0.036860 integral_std=2.026773 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(4,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=0.031663 integral_std=2.127916 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(0,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=0.021007 integral_std=2.173151 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(2,3) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=-0.047275 integral_std=2.082226 log_ratio=-113.4599 accept=0.0000 swapped=False
# i=5 pair=(7,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.030946 integral_std=2.087227 log_ratio=-74.2699 accept=0.0000 swapped=False
# i=6 pair=(1,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.036264 integral_std=2.067783 log_ratio=-87.0335 accept=0.0000 swapped=False
# i=6 pair=(0,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=0.036966 integral_std=2.176642 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(3,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=-0.035054 integral_std=2.138588 log_ratio=-84.1296 accept=0.0000 swapped=False
# i=6 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=0.046707 integral_std=2.079950 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(1,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.073714 integral_std=2.029276 log_ratio=-176.9142 accept=0.0000 swapped=False
# i=6 pair=(2,0) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=-0.044202 integral_std=2.206648 log_ratio=-106.0859 accept=0.0000 swapped=False
# i=6 pair=(3,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=0.006936 integral_std=2.003200 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.035315 integral_std=2.039397 log_ratio=-84.7560 accept=0.0000 swapped=False
# i=7 pair=(5,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=0.015745 integral_std=2.172446 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(0,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=0.046476 integral_std=2.115895 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(3,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=-0.005089 integral_std=2.068033 log_ratio=-12.2129 accept=0.0000 swapped=False
# i=7 pair=(2,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=-0.052011 integral_std=2.192521 log_ratio=-124.8272 accept=0.0000 swapped=False
# i=7 pair=(7,0) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=-0.004882 integral_std=2.103546 log_ratio=-11.7158 accept=0.0000 swapped=False
# i=7 pair=(3,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=0.016031 integral_std=2.195467 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.028363 integral_std=2.265159 log_ratio=-68.0708 accept=0.0000 swapped=False
# i=8 pair=(5,7) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=0.020880 integral_std=2.381485 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(0,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=0.083691 integral_std=2.269816 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.107714 integral_std=2.365327 log_ratio=-258.5148 accept=0.0000 swapped=False
# i=8 pair=(1,2) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.019695 integral_std=2.271138 log_ratio=-47.2684 accept=0.0000 swapped=False
# i=8 pair=(7,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=-0.008857 integral_std=2.314152 log_ratio=-21.2574 accept=0.0000 swapped=False
# i=8 pair=(6,0) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.093986 integral_std=2.245296 log_ratio=-225.5674 accept=0.0000 swapped=False
# i=8 pair=(3,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.185352 integral_std=2.478261 log_ratio=-444.8459 accept=0.0000 swapped=False
# i=9 pair=(2,7) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.027820 integral_std=2.407456 log_ratio=-66.7674 accept=0.0000 swapped=False
# i=9 pair=(5,6) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=0.088987 integral_std=2.378271 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(0,3) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=0.079120 integral_std=2.626080 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(2,7) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.203631 integral_std=2.737819 log_ratio=-488.7153 accept=0.0000 swapped=False
# i=9 pair=(6,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=-0.097192 integral_std=2.435355 log_ratio=-233.2612 accept=0.0000 swapped=False
# ...
# i=4 pair=(1,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=0.156978 integral_std=2.130370 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(3,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=0.021394 integral_std=2.127172 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(5,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=0.150446 integral_std=2.109788 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(4,7) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=0.052025 integral_std=2.182419 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(0,1) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.001621 integral_mean=-0.079959 integral_std=2.095577 log_ratio=-191.9012 accept=0.0000 swapped=False
# i=4 pair=(2,3) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.998833 integral_mean=0.061505 integral_std=1.937045 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(6,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.998447 integral_mean=-0.085811 integral_std=2.101441 log_ratio=-205.9452 accept=0.0000 swapped=False
# i=4 pair=(7,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.998393 integral_mean=-0.042442 integral_std=2.200273 log_ratio=-101.8617 accept=0.0000 swapped=False
# i=5 pair=(1,3) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=0.198409 integral_std=2.273725 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(2,6) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=-0.019270 integral_std=2.036348 log_ratio=-46.2488 accept=0.0000 swapped=False
# i=5 pair=(5,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=0.037949 integral_std=2.245327 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.999378 integral_mean=-0.145031 integral_std=2.162965 log_ratio=-348.0752 accept=0.0000 swapped=False
# i=5 pair=(2,6) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.997811 integral_mean=-0.062665 integral_std=2.077315 log_ratio=-150.3954 accept=0.0000 swapped=False
# i=5 pair=(7,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.997594 integral_mean=-0.021139 integral_std=2.357356 log_ratio=-50.7338 accept=0.0000 swapped=False
# i=6 pair=(0,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=0.084117 integral_std=2.068966 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(1,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=0.128385 integral_std=2.148353 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(6,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=0.069369 integral_std=2.327715 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(5,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.287842 integral_std=2.674035 log_ratio=-690.8200 accept=0.0000 swapped=False
# i=6 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.003397 integral_mean=-0.060086 integral_std=2.107243 log_ratio=-144.2067 accept=0.0000 swapped=False
# i=6 pair=(2,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.997562 integral_mean=-0.147973 integral_std=2.105210 log_ratio=-355.1342 accept=0.0000 swapped=False
# i=6 pair=(7,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.996756 integral_mean=-0.025295 integral_std=2.250023 log_ratio=-60.7074 accept=0.0000 swapped=False
# i=6 pair=(5,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.996644 integral_mean=-0.303142 integral_std=2.645239 log_ratio=-727.5411 accept=0.0000 swapped=False
# i=7 pair=(0,2) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=0.082411 integral_std=2.135367 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(1,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=-0.063417 integral_std=2.440563 log_ratio=-152.2015 accept=0.0000 swapped=False
# i=7 pair=(6,5) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=0.028280 integral_std=2.390864 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(2,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998884 integral_mean=0.153767 integral_std=2.292721 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(1,7) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.996078 integral_mean=-0.129476 integral_std=2.274292 log_ratio=-310.7419 accept=0.0000 swapped=False
# i=7 pair=(5,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.995690 integral_mean=-0.030192 integral_std=2.322466 log_ratio=-72.4620 accept=0.0000 swapped=False
# i=8 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.081799 integral_std=2.241196 log_ratio=-196.3165 accept=0.0000 swapped=False
# i=8 pair=(2,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=0.174133 integral_std=2.491731 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,5) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=0.130433 integral_std=2.322952 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.255272 integral_std=2.733144 log_ratio=-612.6532 accept=0.0000 swapped=False
# i=8 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.005455 integral_mean=-0.134378 integral_std=2.183461 log_ratio=-322.5065 accept=0.0000 swapped=False
# i=8 pair=(1,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.996098 integral_mean=-0.051603 integral_std=2.373046 log_ratio=-123.8464 accept=0.0000 swapped=False
# i=8 pair=(5,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.994812 integral_mean=-0.139375 integral_std=2.327390 log_ratio=-334.4993 accept=0.0000 swapped=False
# i=8 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.994633 integral_mean=-0.251497 integral_std=2.457909 log_ratio=-603.5921 accept=0.0000 swapped=False
# i=9 pair=(0,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.060575 integral_std=2.412033 log_ratio=-145.3805 accept=0.0000 swapped=False
# i=9 pair=(2,5) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=0.186069 integral_std=2.714342 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(7,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=0.136759 integral_std=2.596568 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(0,1) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.998364 integral_mean=-0.036587 integral_std=2.279453 log_ratio=-87.8076 accept=0.0000 swapped=False
# i=9 pair=(5,2) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.994260 integral_mean=-0.139595 integral_std=2.808736 log_ratio=-335.0282 accept=0.0000 swapped=False
# i=9 pair=(6,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.993693 integral_mean=-0.052299 integral_std=2.586996 log_ratio=-125.5168 accept=0.0000 swapped=False
# i=10 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.121670 integral_std=2.401639 log_ratio=-292.0069 accept=0.0000 swapped=False
# i=10 pair=(1,5) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=0.097548 integral_std=3.049897 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(2,6) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=0.019057 integral_std=2.775320 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(7,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=-0.328989 integral_std=3.592356 log_ratio=-789.5731 accept=0.0000 swapped=False
# i=10 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.007448 integral_mean=-0.073915 integral_std=2.290271 log_ratio=-177.3970 accept=0.0000 swapped=False
# i=10 pair=(5,1) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.994690 integral_mean=-0.161403 integral_std=3.201640 log_ratio=-387.3680 accept=0.0000 swapped=False
# i=10 pair=(6,2) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.992942 integral_mean=0.054931 integral_std=2.631465 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(7,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.992700 integral_mean=-0.180914 integral_std=2.871830 log_ratio=-434.1931 accept=0.0000 swapped=False
# i=11 pair=(0,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=0.075942 integral_std=3.657048 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,2) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=0.085901 integral_std=3.219825 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(6,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=0.017235 integral_std=3.526389 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(5,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997906 integral_mean=-0.106083 integral_std=3.386806 log_ratio=-254.5990 accept=0.0000 swapped=False
# i=11 pair=(2,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.992664 integral_mean=-0.008108 integral_std=3.378637 log_ratio=-19.4587 accept=0.0000 swapped=False
# i=11 pair=(7,6) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.991939 integral_mean=-0.141119 integral_std=3.746878 log_ratio=-338.6853 accept=0.0000 swapped=False
# i=12 pair=(3,5) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=0.077210 integral_std=4.166792 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(0,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=-0.085396 integral_std=3.264873 log_ratio=-204.9509 accept=0.0000 swapped=False
# i=12 pair=(1,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=-0.376146 integral_std=5.755433 log_ratio=-902.7512 accept=0.0000 swapped=False
# i=12 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=0.291104 integral_std=6.074875 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(5,3) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009038 integral_mean=0.011888 integral_std=3.926266 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(0,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.993573 integral_mean=-0.141320 integral_std=2.779842 log_ratio=-339.1675 accept=0.0000 swapped=False
# i=12 pair=(1,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.991462 integral_mean=-0.168229 integral_std=4.801246 log_ratio=-403.7503 accept=0.0000 swapped=False
# i=12 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.991169 integral_mean=-0.524274 integral_std=5.770050 log_ratio=-1258.2563 accept=0.0000 swapped=False
# i=13 pair=(5,0) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=0.050105 integral_std=5.881635 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(2,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=-0.108853 integral_std=6.768260 log_ratio=-261.2472 accept=0.0000 swapped=False
# i=13 pair=(7,4) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=0.040537 integral_std=8.766397 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(0,5) lam_t=1.00254 lam_s=1.00722 tsr_diff=0.997588 integral_mean=-0.012356 integral_std=5.684858 log_ratio=-29.6534 accept=0.0000 swapped=False
# i=13 pair=(2,1) lam_t=1.00896 lam_s=1.00961 tsr_diff=0.991555 integral_mean=-0.080325 integral_std=6.943474 log_ratio=-192.7802 accept=0.0000 swapped=False
# i=13 pair=(4,7) lam_t=1.00986 lam_s=1.00995 tsr_diff=0.990722 integral_mean=0.540001 integral_std=7.586632 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.082172 integral_std=6.536571 log_ratio=-197.2127 accept=0.0000 swapped=False
# i=14 pair=(5,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=-2.111133 integral_std=32.411610 log_ratio=-5066.7192 accept=0.0000 swapped=False
# i=14 pair=(1,7) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=0.090403 integral_std=20.992687 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(4,6) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=0.054661 integral_std=15.666221 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(3,0) lam_t=0.99000 lam_s=1.00254 tsr_diff=1.009951 integral_mean=-0.050743 integral_std=6.499333 log_ratio=-121.7829 accept=0.0000 swapped=False
# i=14 pair=(5,2) lam_t=1.00722 lam_s=1.00896 tsr_diff=0.992935 integral_mean=-0.724796 integral_std=10.321426 log_ratio=-1739.5115 accept=0.0000 swapped=False
# i=14 pair=(7,1) lam_t=1.00961 lam_s=1.00986 tsr_diff=0.990616 integral_mean=2.213581 integral_std=41.686680 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(6,4) lam_t=1.00995 lam_s=1.01000 tsr_diff=0.990295 integral_mean=-0.799891 integral_std=15.510201 log_ratio=-1919.7373 accept=0.0000 swapped=False
# Best Sample: 0 log probability -0.012
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-16 22:33:22/40/rollout.png
# Success Rate: 82.5, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14eb88858e50>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14eb93ccc640>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14eb93cabec0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14eb9250e950>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14eb93ccc640>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14eb93cabec0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14eb88858e50>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14eb93ccc640>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14eb886b1440>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14eb9250e950>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14eb93ccc640>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14eb886b1440>,
# 	),
# 	result = 0
# )
