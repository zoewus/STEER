# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.9 --lam_end 1.1 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000005 integral_std=0.000314 log_ratio=-0.0125 accept=0.9876 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000005 integral_std=0.000302 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=-0.000010 integral_std=0.000327 log_ratio=-0.0233 accept=0.9769 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=0.000007 integral_std=0.001272 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=0.000040 integral_std=0.001303 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=-0.000110 integral_std=0.001325 log_ratio=-0.2636 accept=0.7683 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=-0.000069 integral_std=0.001196 log_ratio=-0.1667 accept=0.8464 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=-0.000002 integral_std=0.002717 log_ratio=-0.0048 accept=0.9952 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000057 integral_std=0.002804 log_ratio=-0.1374 accept=0.8716 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=0.000071 integral_std=0.002632 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(3,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=0.000027 integral_std=0.004833 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(1,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=-0.000172 integral_std=0.004959 log_ratio=-0.4123 accept=0.6622 swapped=False
# i=4 pair=(0,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=-0.000016 integral_std=0.004620 log_ratio=-0.0381 accept=0.9626 swapped=True
# i=4 pair=(2,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=0.000064 integral_std=0.004697 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,1) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=-0.000008 integral_std=0.008157 log_ratio=-0.0186 accept=0.9816 swapped=True
# i=5 pair=(7,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=-0.000088 integral_std=0.007189 log_ratio=-0.2116 accept=0.8093 swapped=True
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=-0.000211 integral_std=0.008004 log_ratio=-0.5069 accept=0.6024 swapped=True
# i=6 pair=(5,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=-0.000242 integral_std=0.011707 log_ratio=-0.5797 accept=0.5601 swapped=True
# i=6 pair=(3,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=-0.000317 integral_std=0.011439 log_ratio=-0.7606 accept=0.4674 swapped=False
# i=6 pair=(7,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=-0.000444 integral_std=0.010179 log_ratio=-1.0666 accept=0.3442 swapped=True
# i=6 pair=(0,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=0.000347 integral_std=0.010372 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(5,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=-0.000108 integral_std=0.015764 log_ratio=-0.2600 accept=0.7710 swapped=True
# i=7 pair=(6,4) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=-0.000113 integral_std=0.015561 log_ratio=-0.2714 accept=0.7623 swapped=True
# i=7 pair=(7,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=-0.000060 integral_std=0.014331 log_ratio=-0.1436 accept=0.8662 swapped=True
# i=8 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=0.001285 integral_std=0.023854 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(5,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=-0.000370 integral_std=0.021884 log_ratio=-0.8874 accept=0.4117 swapped=True
# i=8 pair=(6,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.000597 integral_std=0.020819 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=-0.001262 integral_std=0.019201 log_ratio=-3.0290 accept=0.0484 swapped=False
# i=9 pair=(1,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=-0.000045 integral_std=0.030825 log_ratio=-0.1070 accept=0.8985 swapped=True
# i=9 pair=(5,2) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.001933 integral_std=0.028583 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(6,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=0.000079 integral_std=0.025984 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(3,4) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.000103 integral_std=0.041353 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.000630 integral_std=0.033691 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=-0.000509 integral_std=0.035998 log_ratio=-1.2217 accept=0.2947 swapped=True
# i=10 pair=(6,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=-0.003782 integral_std=0.041978 log_ratio=-9.0758 accept=0.0001 swapped=False
# i=11 pair=(3,2) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=0.000755 integral_std=0.067789 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=0.000651 integral_std=0.054447 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(5,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=-0.000100 integral_std=0.035367 log_ratio=-0.2406 accept=0.7862 swapped=True
# i=12 pair=(4,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.005476 integral_std=0.100820 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(3,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=-0.000574 integral_std=0.101464 log_ratio=-1.3775 accept=0.2522 swapped=False
# i=12 pair=(1,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=0.002577 integral_std=0.067964 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(5,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=-0.006226 integral_std=0.094797 log_ratio=-14.9433 accept=0.0000 swapped=False
# i=13 pair=(4,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.008488 integral_std=0.151771 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(7,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.007981 integral_std=0.117281 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(1,5) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=-0.000266 integral_std=0.106122 log_ratio=-0.6390 accept=0.5278 swapped=False
# i=14 pair=(2,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.128291 integral_std=0.898586 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(4,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=0.075643 integral_std=0.638876 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(7,1) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=0.024131 integral_std=0.526801 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(5,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.138630 integral_std=1.030303 log_ratio=-332.7123 accept=0.0000 swapped=False
# Best Sample: 2 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/1/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000002 integral_std=0.000293 log_ratio=-0.0060 accept=0.9941 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000008 integral_std=0.000305 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=-0.000002 integral_std=0.000292 log_ratio=-0.0046 accept=0.9955 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=0.000005 integral_std=0.001246 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=0.000003 integral_std=0.001286 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=0.000108 integral_std=0.001215 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=0.000042 integral_std=0.001223 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=-0.000009 integral_std=0.002721 log_ratio=-0.0211 accept=0.9792 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=0.000195 integral_std=0.002939 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=-0.000120 integral_std=0.002881 log_ratio=-0.2880 accept=0.7498 swapped=True
# i=4 pair=(3,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=0.000098 integral_std=0.005417 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(1,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=-0.000043 integral_std=0.004626 log_ratio=-0.1034 accept=0.9017 swapped=True
# i=4 pair=(0,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=-0.000006 integral_std=0.004885 log_ratio=-0.0150 accept=0.9851 swapped=True
# i=4 pair=(2,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=-0.000137 integral_std=0.005182 log_ratio=-0.3286 accept=0.7200 swapped=True
# i=5 pair=(3,7) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=0.000352 integral_std=0.007637 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(1,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=-0.000288 integral_std=0.008118 log_ratio=-0.6903 accept=0.5014 swapped=False
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=-0.000640 integral_std=0.008049 log_ratio=-1.5358 accept=0.2153 swapped=True
# i=6 pair=(5,7) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=0.000071 integral_std=0.012005 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(3,1) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=-0.000124 integral_std=0.011213 log_ratio=-0.2985 accept=0.7419 swapped=False
# i=6 pair=(6,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=0.000023 integral_std=0.012449 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(0,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=0.000154 integral_std=0.010490 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(5,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=0.000136 integral_std=0.016927 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(1,4) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=-0.000386 integral_std=0.017403 log_ratio=-0.9269 accept=0.3958 swapped=True
# i=7 pair=(6,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=0.000272 integral_std=0.014646 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=-0.000267 integral_std=0.023089 log_ratio=-0.6411 accept=0.5267 swapped=False
# i=8 pair=(5,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=0.001056 integral_std=0.026941 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.000215 integral_std=0.019152 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(6,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=0.000329 integral_std=0.022103 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(3,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=0.002109 integral_std=0.040328 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(5,2) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.003007 integral_std=0.035405 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(1,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=-0.000823 integral_std=0.031817 log_ratio=-1.9748 accept=0.1388 swapped=False
# i=10 pair=(7,4) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=-0.000364 integral_std=0.057937 log_ratio=-0.8738 accept=0.4174 swapped=False
# i=10 pair=(3,2) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.002565 integral_std=0.044420 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,1) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=0.003748 integral_std=0.044632 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(0,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=-0.002046 integral_std=0.051823 log_ratio=-4.9106 accept=0.0074 swapped=False
# i=11 pair=(4,2) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=0.005303 integral_std=0.091044 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(3,1) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=0.004419 integral_std=0.059759 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(5,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=0.001607 integral_std=0.092029 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(7,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.008661 integral_std=0.118003 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(4,1) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.019729 integral_std=0.133005 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(3,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=0.015739 integral_std=0.224042 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(5,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=0.000204 integral_std=0.144763 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(7,1) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.018273 integral_std=0.139807 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(4,0) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.003529 integral_std=0.334097 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(3,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=0.000918 integral_std=0.280194 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(2,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.073516 integral_std=0.823188 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(7,0) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=-0.055564 integral_std=1.891837 log_ratio=-133.3548 accept=0.0000 swapped=False
# i=14 pair=(4,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=-0.162434 integral_std=1.653838 log_ratio=-389.8425 accept=0.0000 swapped=False
# i=14 pair=(3,5) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.193535 integral_std=2.110971 log_ratio=-464.4829 accept=0.0000 swapped=False
# Best Sample: 1 log probability -0.283
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/2/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000003 integral_std=0.000310 log_ratio=-0.0060 accept=0.9940 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000003 integral_std=0.000312 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=0.000003 integral_std=0.000304 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=-0.000049 integral_std=0.001238 log_ratio=-0.1165 accept=0.8900 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=-0.000057 integral_std=0.001261 log_ratio=-0.1361 accept=0.8728 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=-0.000000 integral_std=0.001178 log_ratio=-0.0008 accept=0.9992 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=-0.000144 integral_std=0.001341 log_ratio=-0.3466 accept=0.7071 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=0.000039 integral_std=0.002840 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000060 integral_std=0.002606 log_ratio=-0.1436 accept=0.8662 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=-0.000326 integral_std=0.002966 log_ratio=-0.7830 accept=0.4570 swapped=False
# i=4 pair=(3,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=0.000016 integral_std=0.004891 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(1,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=-0.000603 integral_std=0.005352 log_ratio=-1.4482 accept=0.2350 swapped=False
# i=4 pair=(0,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=0.000046 integral_std=0.004519 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(6,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=0.000194 integral_std=0.004736 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,1) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=0.000063 integral_std=0.007997 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(7,2) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=0.000187 integral_std=0.007791 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=-0.000173 integral_std=0.007369 log_ratio=-0.4147 accept=0.6605 swapped=True
# i=6 pair=(5,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=0.000904 integral_std=0.011996 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(3,2) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=-0.000064 integral_std=0.011163 log_ratio=-0.1533 accept=0.8579 swapped=True
# i=6 pair=(7,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=0.000438 integral_std=0.010341 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(0,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=-0.000027 integral_std=0.010881 log_ratio=-0.0643 accept=0.9377 swapped=True
# i=7 pair=(5,2) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=0.000692 integral_std=0.016439 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(3,4) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=-0.000069 integral_std=0.016705 log_ratio=-0.1646 accept=0.8482 swapped=True
# i=7 pair=(7,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=0.000352 integral_std=0.014528 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=-0.000430 integral_std=0.021321 log_ratio=-1.0313 accept=0.3566 swapped=False
# i=8 pair=(5,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=0.000718 integral_std=0.023123 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.001528 integral_std=0.023034 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=-0.000629 integral_std=0.020860 log_ratio=-1.5101 accept=0.2209 swapped=False
# i=9 pair=(2,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=-0.000438 integral_std=0.034498 log_ratio=-1.0505 accept=0.3498 swapped=False
# i=9 pair=(5,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.001039 integral_std=0.030878 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(3,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=0.001018 integral_std=0.034142 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.001290 integral_std=0.040354 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(4,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.003273 integral_std=0.044477 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=-0.001536 integral_std=0.048575 log_ratio=-3.6872 accept=0.0250 swapped=False
# i=10 pair=(3,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=0.002387 integral_std=0.041954 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=0.005506 integral_std=0.075399 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(4,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=-0.000923 integral_std=0.067310 log_ratio=-2.2159 accept=0.1091 swapped=True
# i=11 pair=(7,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=0.003105 integral_std=0.062494 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(2,6) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.006402 integral_std=0.118145 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.003276 integral_std=0.086739 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(4,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=0.002274 integral_std=0.070296 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(7,3) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=-0.014907 integral_std=0.148933 log_ratio=-35.7771 accept=0.0000 swapped=False
# i=13 pair=(2,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.009494 integral_std=0.096790 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(1,0) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.005744 integral_std=0.065333 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=-0.005613 integral_std=0.167752 log_ratio=-13.4702 accept=0.0000 swapped=False
# i=14 pair=(6,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.045758 integral_std=0.736761 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(2,0) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=0.040537 integral_std=0.176863 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(1,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=0.049652 integral_std=0.209746 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(7,3) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.542859 integral_std=2.476703 log_ratio=-1302.8623 accept=0.0000 swapped=False
# Best Sample: 0 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/3/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=0.000006 integral_std=0.000325 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000012 integral_std=0.000312 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=0.000005 integral_std=0.000318 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=-0.000010 integral_std=0.001183 log_ratio=-0.0241 accept=0.9762 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=0.000012 integral_std=0.001215 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=0.000049 integral_std=0.001290 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=-0.000056 integral_std=0.001182 log_ratio=-0.1340 accept=0.8746 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=-0.000538 integral_std=0.003475 log_ratio=-1.2905 accept=0.2751 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000085 integral_std=0.002941 log_ratio=-0.2034 accept=0.8160 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=0.001173 integral_std=0.004470 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(3,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=-0.000228 integral_std=0.005340 log_ratio=-0.5463 accept=0.5791 swapped=True
# i=4 pair=(1,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=-0.000354 integral_std=0.005006 log_ratio=-0.8507 accept=0.4271 swapped=False
# i=4 pair=(0,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=-0.000134 integral_std=0.004803 log_ratio=-0.3225 accept=0.7243 swapped=True
# i=4 pair=(2,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=0.001349 integral_std=0.006918 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,1) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=0.000118 integral_std=0.007910 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(7,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=0.000201 integral_std=0.007866 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=-0.000397 integral_std=0.007633 log_ratio=-0.9540 accept=0.3852 swapped=True
# i=6 pair=(5,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=-0.000017 integral_std=0.012835 log_ratio=-0.0410 accept=0.9598 swapped=True
# i=6 pair=(3,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=0.000161 integral_std=0.011522 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(7,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=-0.000053 integral_std=0.011069 log_ratio=-0.1277 accept=0.8801 swapped=True
# i=6 pair=(0,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=-0.003037 integral_std=0.013917 log_ratio=-7.2886 accept=0.0007 swapped=False
# i=7 pair=(5,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=-0.000587 integral_std=0.017059 log_ratio=-1.4085 accept=0.2445 swapped=False
# i=7 pair=(3,4) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=-0.000027 integral_std=0.015059 log_ratio=-0.0659 accept=0.9362 swapped=True
# i=7 pair=(7,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=0.000306 integral_std=0.014872 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(1,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=0.000257 integral_std=0.024063 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(6,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=0.000422 integral_std=0.021326 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=-0.000159 integral_std=0.017869 log_ratio=-0.3804 accept=0.6836 swapped=True
# i=8 pair=(7,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=-0.002771 integral_std=0.023538 log_ratio=-6.6494 accept=0.0013 swapped=False
# i=9 pair=(1,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=-0.000139 integral_std=0.030547 log_ratio=-0.3332 accept=0.7166 swapped=False
# i=9 pair=(6,0) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=-0.000624 integral_std=0.026077 log_ratio=-1.4982 accept=0.2235 swapped=False
# i=9 pair=(3,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=0.000018 integral_std=0.030065 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.000959 integral_std=0.048112 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(4,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.000569 integral_std=0.037440 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(0,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=0.000515 integral_std=0.042576 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(3,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=-0.002321 integral_std=0.044395 log_ratio=-5.5715 accept=0.0038 swapped=False
# i=11 pair=(5,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=-0.000572 integral_std=0.064574 log_ratio=-1.3732 accept=0.2533 swapped=False
# i=11 pair=(4,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=-0.000256 integral_std=0.059738 log_ratio=-0.6151 accept=0.5406 swapped=False
# i=11 pair=(0,3) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=0.000663 integral_std=0.041060 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.006217 integral_std=0.112407 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(6,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.005583 integral_std=0.097634 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(7,3) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=0.002026 integral_std=0.097778 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(0,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=0.004588 integral_std=0.091079 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(1,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.007675 integral_std=0.211802 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(6,3) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.015897 integral_std=0.167323 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(7,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=0.009876 integral_std=0.194333 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(5,4) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.083920 integral_std=0.917995 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(1,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=0.025588 integral_std=0.169421 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(6,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=0.088360 integral_std=0.996487 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(7,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=0.029106 integral_std=0.830956 log_ratio=0.0000 accept=1.0000 swapped=True
# Best Sample: 3 log probability -0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/4/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/4/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000004 integral_std=0.000321 log_ratio=-0.0107 accept=0.9893 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000009 integral_std=0.000289 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=0.000009 integral_std=0.000295 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=-0.000025 integral_std=0.001521 log_ratio=-0.0592 accept=0.9426 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=-0.000006 integral_std=0.001169 log_ratio=-0.0135 accept=0.9866 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=0.000009 integral_std=0.001220 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=0.000009 integral_std=0.001128 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=0.000221 integral_std=0.003101 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000019 integral_std=0.002708 log_ratio=-0.0451 accept=0.9559 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=-0.000059 integral_std=0.003102 log_ratio=-0.1415 accept=0.8681 swapped=True
# i=4 pair=(3,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=-0.000370 integral_std=0.005310 log_ratio=-0.8889 accept=0.4111 swapped=True
# i=4 pair=(1,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=0.000071 integral_std=0.004887 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(0,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=0.000200 integral_std=0.005035 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(2,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=0.000184 integral_std=0.004525 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(3,7) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=0.000377 integral_std=0.007480 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(1,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=0.000100 integral_std=0.007890 log_ratio=0.0000 accept=1.0000 swapped=True
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=0.000180 integral_std=0.007094 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(5,7) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=0.000674 integral_std=0.011513 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(3,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=0.000111 integral_std=0.011917 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(1,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=-0.000231 integral_std=0.010068 log_ratio=-0.5544 accept=0.5744 swapped=True
# i=6 pair=(0,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=0.000105 integral_std=0.010402 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(5,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=0.000352 integral_std=0.017985 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(3,4) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=0.001245 integral_std=0.016192 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(1,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=-0.000228 integral_std=0.014328 log_ratio=-0.5484 accept=0.5779 swapped=False
# i=8 pair=(7,6) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=-0.000896 integral_std=0.027360 log_ratio=-2.1507 accept=0.1164 swapped=False
# i=8 pair=(5,4) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=0.000538 integral_std=0.021538 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,1) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.001125 integral_std=0.022094 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(2,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=0.000320 integral_std=0.019589 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(6,4) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=0.002816 integral_std=0.033494 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(5,1) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.001197 integral_std=0.027856 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(3,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=0.001106 integral_std=0.030451 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(7,4) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.000754 integral_std=0.046113 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(6,1) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.001052 integral_std=0.046788 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=0.001007 integral_std=0.038842 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(3,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=-0.000147 integral_std=0.058374 log_ratio=-0.3532 accept=0.7024 swapped=True
# i=11 pair=(7,1) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=-0.000727 integral_std=0.065815 log_ratio=-1.7455 accept=0.1746 swapped=False
# i=11 pair=(6,0) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=0.012464 integral_std=0.101218 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(5,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=-0.001233 integral_std=0.061748 log_ratio=-2.9587 accept=0.0519 swapped=False
# i=12 pair=(4,7) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.008683 integral_std=0.124813 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,0) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.001862 integral_std=0.064054 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(6,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=0.012069 integral_std=0.107540 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(2,3) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=-0.017582 integral_std=0.138198 log_ratio=-42.1956 accept=0.0000 swapped=False
# i=13 pair=(4,0) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.009251 integral_std=0.195471 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(1,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.004303 integral_std=0.116371 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(6,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=-0.091869 integral_std=0.575191 log_ratio=-220.4859 accept=0.0000 swapped=False
# i=14 pair=(7,0) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.063108 integral_std=0.807717 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(4,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=0.066389 integral_std=0.863089 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(1,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=-0.547636 integral_std=2.901810 log_ratio=-1314.3265 accept=0.0000 swapped=False
# i=14 pair=(2,3) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.068834 integral_std=1.607131 log_ratio=-165.2017 accept=0.0000 swapped=False
# Best Sample: 7 log probability -1.373
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/5/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/5/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000001 integral_std=0.000294 log_ratio=-0.0033 accept=0.9967 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=-0.000000 integral_std=0.000318 log_ratio=-0.0004 accept=0.9996 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=-0.000011 integral_std=0.000308 log_ratio=-0.0274 accept=0.9730 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=0.000047 integral_std=0.001288 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=-0.000042 integral_std=0.001262 log_ratio=-0.1018 accept=0.9032 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=0.000026 integral_std=0.001171 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=-0.000014 integral_std=0.001236 log_ratio=-0.0336 accept=0.9669 swapped=True
# i=3 pair=(1,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=0.000063 integral_std=0.002951 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000064 integral_std=0.002789 log_ratio=-0.1536 accept=0.8576 swapped=True
# ...
# i=8 pair=(5,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.001596 integral_std=0.020309 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,0) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=0.004303 integral_std=0.030443 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(1,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=0.001133 integral_std=0.035916 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(3,2) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.000864 integral_std=0.023814 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(5,0) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=0.001709 integral_std=0.031014 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(4,6) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.001635 integral_std=0.054379 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.001883 integral_std=0.033431 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(3,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=-0.000977 integral_std=0.046107 log_ratio=-2.3448 accept=0.0959 swapped=False
# i=10 pair=(5,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=-0.006011 integral_std=0.068165 log_ratio=-14.4267 accept=0.0000 swapped=False
# i=11 pair=(4,2) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=0.004983 integral_std=0.062701 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,3) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=0.001092 integral_std=0.042900 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(0,5) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=-0.010343 integral_std=0.079016 log_ratio=-24.8224 accept=0.0000 swapped=False
# i=12 pair=(6,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.007317 integral_std=0.101774 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(4,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.005939 integral_std=0.095491 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=-0.001278 integral_std=0.100716 log_ratio=-3.0679 accept=0.0465 swapped=False
# i=12 pair=(5,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=-0.009645 integral_std=0.263609 log_ratio=-23.1486 accept=0.0000 swapped=False
# i=13 pair=(6,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.010357 integral_std=0.178215 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(4,1) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.018536 integral_std=0.181763 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(0,5) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=-0.087619 integral_std=0.384736 log_ratio=-210.2863 accept=0.0000 swapped=False
# i=14 pair=(2,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.055105 integral_std=0.355342 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(6,1) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=0.084762 integral_std=0.426989 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(4,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=0.113841 integral_std=1.013005 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(5,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.001116 integral_std=3.615108 log_ratio=-2.6775 accept=0.0687 swapped=False
# Best Sample: 1 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/39/rollout.png
# i=0 pair=(0,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(2,3) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(4,5) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=0 pair=(6,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.000000 integral_mean=0.000000 integral_std=0.000000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(0,3) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.000305 integral_mean=-0.000023 integral_std=0.000331 log_ratio=-0.0556 accept=0.9459 swapped=True
# i=1 pair=(2,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.000305 integral_mean=0.000043 integral_std=0.000373 log_ratio=0.0000 accept=1.0000 swapped=True
# i=1 pair=(4,7) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.000304 integral_mean=0.000014 integral_std=0.000315 log_ratio=0.0000 accept=1.0000 swapped=True
# i=2 pair=(1,3) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.001215 integral_mean=-0.000282 integral_std=0.001641 log_ratio=-0.6762 accept=0.5086 swapped=False
# i=2 pair=(0,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.001209 integral_mean=-0.000067 integral_std=0.001281 log_ratio=-0.1603 accept=0.8519 swapped=True
# i=2 pair=(2,7) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.001204 integral_mean=-0.000016 integral_std=0.001352 log_ratio=-0.0394 accept=0.9613 swapped=True
# i=2 pair=(4,6) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.001198 integral_mean=0.000028 integral_std=0.001242 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(3,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.002695 integral_mean=0.000114 integral_std=0.002893 log_ratio=0.0000 accept=1.0000 swapped=True
# i=3 pair=(0,7) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.002667 integral_mean=-0.000255 integral_std=0.003016 log_ratio=-0.6123 accept=0.5421 swapped=True
# i=3 pair=(2,6) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.002638 integral_mean=0.000090 integral_std=0.002747 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(1,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.004754 integral_mean=0.000128 integral_std=0.005663 log_ratio=0.0000 accept=1.0000 swapped=True
# i=4 pair=(3,7) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.004666 integral_mean=-0.000157 integral_std=0.005257 log_ratio=-0.3760 accept=0.6866 swapped=True
# i=4 pair=(0,6) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.004580 integral_mean=-0.000019 integral_std=0.004673 log_ratio=-0.0467 accept=0.9544 swapped=True
# i=4 pair=(2,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.004497 integral_mean=-0.000120 integral_std=0.004882 log_ratio=-0.2869 accept=0.7506 swapped=True
# i=5 pair=(1,7) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.007191 integral_mean=-0.000251 integral_std=0.008952 log_ratio=-0.6016 accept=0.5479 swapped=False
# i=5 pair=(3,6) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.006992 integral_mean=-0.000070 integral_std=0.007097 log_ratio=-0.1690 accept=0.8445 swapped=True
# i=5 pair=(0,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.006800 integral_mean=-0.000315 integral_std=0.007666 log_ratio=-0.7563 accept=0.4694 swapped=False
# i=6 pair=(5,1) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.010258 integral_mean=-0.000175 integral_std=0.012264 log_ratio=-0.4190 accept=0.6577 swapped=True
# i=6 pair=(7,6) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.009862 integral_mean=0.000224 integral_std=0.012490 log_ratio=0.0000 accept=1.0000 swapped=True
# i=6 pair=(3,0) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.009487 integral_mean=-0.000085 integral_std=0.010914 log_ratio=-0.2041 accept=0.8154 swapped=True
# i=6 pair=(4,2) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.009134 integral_mean=0.002917 integral_std=0.017512 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(5,6) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.013204 integral_mean=-0.000013 integral_std=0.017110 log_ratio=-0.0307 accept=0.9697 swapped=True
# i=7 pair=(7,0) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.012549 integral_mean=0.000860 integral_std=0.017067 log_ratio=0.0000 accept=1.0000 swapped=True
# i=7 pair=(3,2) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.011942 integral_mean=-0.000264 integral_std=0.016664 log_ratio=-0.6327 accept=0.5312 swapped=True
# i=8 pair=(1,6) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.017050 integral_mean=0.000233 integral_std=0.027636 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(5,0) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.015993 integral_mean=0.000271 integral_std=0.023538 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(7,2) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.015031 integral_mean=0.000405 integral_std=0.021015 log_ratio=0.0000 accept=1.0000 swapped=True
# i=8 pair=(3,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.014154 integral_mean=-0.003018 integral_std=0.025253 log_ratio=-7.2443 accept=0.0007 swapped=False
# i=9 pair=(1,0) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.019834 integral_mean=0.000861 integral_std=0.028820 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(5,2) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.018401 integral_mean=0.000498 integral_std=0.032530 log_ratio=0.0000 accept=1.0000 swapped=True
# i=9 pair=(7,3) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.017118 integral_mean=-0.000792 integral_std=0.037094 log_ratio=-1.9019 accept=0.1493 swapped=True
# i=10 pair=(6,0) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.024082 integral_mean=0.001133 integral_std=0.053872 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(1,2) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.022048 integral_mean=0.003971 integral_std=0.052769 log_ratio=0.0000 accept=1.0000 swapped=True
# i=10 pair=(5,3) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.020261 integral_mean=-0.000231 integral_std=0.039389 log_ratio=-0.5536 accept=0.5749 swapped=False
# i=10 pair=(7,4) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.018683 integral_mean=0.000356 integral_std=0.057000 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(6,2) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.025947 integral_mean=0.005243 integral_std=0.079182 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(1,5) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.023559 integral_mean=0.000129 integral_std=0.062774 log_ratio=0.0000 accept=1.0000 swapped=True
# i=11 pair=(3,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.021487 integral_mean=-0.009277 integral_std=0.073620 log_ratio=-22.2650 accept=0.0000 swapped=False
# i=12 pair=(0,2) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.030032 integral_mean=0.012906 integral_std=0.113955 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(6,5) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.026960 integral_mean=0.001301 integral_std=0.120245 log_ratio=0.0000 accept=1.0000 swapped=True
# i=12 pair=(1,3) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.024335 integral_mean=-0.004869 integral_std=0.108459 log_ratio=-11.6846 accept=0.0000 swapped=False
# i=12 pair=(4,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.022076 integral_mean=-0.007381 integral_std=0.183443 log_ratio=-17.7148 accept=0.0000 swapped=False
# i=13 pair=(0,5) lam_t=0.92857 lam_s=0.95714 tsr_diff=0.030360 integral_mean=0.013876 integral_std=0.272014 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(6,1) lam_t=0.98571 lam_s=1.01429 tsr_diff=0.027152 integral_mean=0.017646 integral_std=0.293065 log_ratio=0.0000 accept=1.0000 swapped=True
# i=13 pair=(3,4) lam_t=1.04286 lam_s=1.07143 tsr_diff=0.024427 integral_mean=0.016397 integral_std=0.274821 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(2,5) lam_t=0.90000 lam_s=0.92857 tsr_diff=0.033594 integral_mean=0.077368 integral_std=1.284576 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(0,1) lam_t=0.95714 lam_s=0.98571 tsr_diff=0.029813 integral_mean=-0.078724 integral_std=0.852943 log_ratio=-188.9383 accept=0.0000 swapped=False
# i=14 pair=(6,4) lam_t=1.01429 lam_s=1.04286 tsr_diff=0.026637 integral_mean=0.025260 integral_std=0.837212 log_ratio=0.0000 accept=1.0000 swapped=True
# i=14 pair=(3,7) lam_t=1.07143 lam_s=1.10000 tsr_diff=0.023942 integral_mean=-0.003225 integral_std=1.903204 log_ratio=-7.7405 accept=0.0004 swapped=False
# Best Sample: 0 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-21 11:52:05/40/rollout.png
# Success Rate: 92.5, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x1487b4adcdc0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1487c01f4d40>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1487c01f7e40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x1487bf16a8c0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1487c01f4d40>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1487c01f7e40>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x1487b4adcdc0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1487c01f4d40>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1487a8081440>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x1487bf16a8c0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1487c01f4d40>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1487a8081440>,
# 	),
# 	result = 0
# )
