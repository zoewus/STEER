# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.95 --lam_end 1.05 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.87 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.56 accept 0.21
# Time 221 1.02 and 1.04 log_ratio -0.87 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.69 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -4.06 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.58 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.69 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.56 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.71 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.76 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.22 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.15 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.85 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.24 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.88 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -29.53 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.29 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.97 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.78 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.25 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.01 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -8.65 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -10.35 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -5.57 accept 0.00
# Best Sample: 5 log probability -0.010
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/1/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.90 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.64 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.83 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.58 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.52 accept 0.01
# Time 187 1.01 and 1.02 log_ratio -3.78 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.70 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.06 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -18.54 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.69 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.16 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -14.14 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.67 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.96 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -18.71 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.63 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.13 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -19.86 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.30 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.41 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.63 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -16.14 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -22.92 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -8.61 accept 0.00
# Best Sample: 4 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/2/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.85 accept 0.16
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.50 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.68 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.85 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.17 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.30 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.35 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.97 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -15.10 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.55 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.24 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.70 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -18.31 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.19 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.73 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -18.34 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -19.65 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -13.81 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.57 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.80 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -15.94 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -5.43 accept 0.00
# Best Sample: 6 log probability -2.639
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/3/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.80 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.48 accept 0.23
# Time 221 1.02 and 1.04 log_ratio -0.88 accept 0.41
# Time 187 0.95 and 0.96 log_ratio -3.44 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.83 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.70 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.79 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.97 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.92 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.23 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.91 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.20 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.40 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.02 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.05 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.13 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.21 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.65 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -21.22 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.68 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.02 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -5.72 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -38.95 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -11.77 accept 0.00
# Best Sample: 6 log probability -0.142
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/4/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/4/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.85 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -1.66 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.83 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.49 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.53 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -4.10 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.83 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.52 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.60 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.90 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.17 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.84 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.08 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -14.16 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.28 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -30.51 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.04 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.75 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -27.69 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.26 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.15 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -18.34 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -17.68 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -6.12 accept 0.00
# Best Sample: 3 log probability -0.220
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/5/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/5/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.83 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.59 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.91 accept 0.40
# Time 187 0.95 and 0.96 log_ratio -3.74 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.90 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.78 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.04 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.98 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.56 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.29 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -10.74 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.26 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.93 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.19 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.71 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -29.62 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.27 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.14 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.79 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.62 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -14.57 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -5.86 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -13.42 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.30 accept 0.01
# Best Sample: 4 log probability -0.093
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/6/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/6/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.65 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.92 accept 0.40
# Time 187 0.95 and 0.96 log_ratio -3.78 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.69 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.49 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -4.01 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.93 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.82 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.77 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.45 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.52 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.37 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.16 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.44 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -37.98 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.48 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.93 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.12 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -18.35 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.91 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.11 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -7.43 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -9.79 accept 0.00
# Best Sample: 3 log probability -0.580
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/7/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/7/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.84 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -1.65 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.85 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.94 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.10 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.89 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.90 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.17 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.66 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.86 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.16 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.17 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.88 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.05 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.14 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.72 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -23.88 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -14.60 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.88 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.18 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.88 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -15.59 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.46 accept 0.01
# Best Sample: 6 log probability -0.413
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/8/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/8/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.77 accept 0.46
# Time 221 0.99 and 1.01 log_ratio -1.77 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -0.87 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.71 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.79 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.86 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.01 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.56 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.85 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.03 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.61 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.70 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.35 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.46 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.29 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.69 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.90 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.31 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.45 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.55 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -18.34 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.93 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -3.17 accept 0.04
# Time 17 1.02 and 1.04 log_ratio -15.32 accept 0.00
# Best Sample: 7 log probability -0.006
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/9/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/9/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -2.09 accept 0.12
# Time 221 1.02 and 1.04 log_ratio -0.81 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.54 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.66 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.66 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -4.45 accept 0.01
# Time 153 0.96 and 0.97 log_ratio -7.80 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.38 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.60 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.73 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -14.08 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.84 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.58 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -19.96 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.06 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.57 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.42 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.46 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.07 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.59 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -12.08 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -13.53 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.22 accept 0.01
# Best Sample: 6 log probability -0.376
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/10/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/10/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.76 accept 0.47
# Time 221 0.99 and 1.01 log_ratio -1.69 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.86 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.75 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.85 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.66 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.74 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.88 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.26 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.59 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.20 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.92 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.54 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.31 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.74 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.53 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.46 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.14 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.08 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.88 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -23.45 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -10.54 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -25.99 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -14.36 accept 0.00
# Best Sample: 4 log probability -0.917
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/11/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/11/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.80 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.61 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.96 accept 0.38
# Time 187 0.95 and 0.96 log_ratio -3.57 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.77 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.69 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.58 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.78 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.74 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.78 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.36 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.25 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.89 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.22 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.12 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.90 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.89 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.00 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.49 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.76 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.07 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.06 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -21.14 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -12.95 accept 0.00
# Best Sample: 1 log probability -0.003
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/12/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/12/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.94 accept 0.39
# Time 221 0.99 and 1.01 log_ratio -1.68 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.55 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.75 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.73 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.76 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.60 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.46 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.78 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.01 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.95 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.05 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.14 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.43 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.96 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.66 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.14 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.45 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.96 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.00 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -10.28 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -16.42 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -7.40 accept 0.00
# Best Sample: 5 log probability -0.010
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/13/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/13/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.61 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -1.03 accept 0.36
# Time 187 0.95 and 0.96 log_ratio -3.61 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.07 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.52 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.92 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.00 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.40 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.52 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.19 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.56 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.87 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.10 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.07 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.26 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.74 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -23.51 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -24.90 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.53 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.38 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -20.27 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -21.57 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.10 accept 0.00
# Best Sample: 4 log probability -0.035
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/14/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/14/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.83 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.67 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.93 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.62 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.61 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.51 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.48 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -14.59 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.89 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -14.61 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.34 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.33 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.11 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.70 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -30.30 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.85 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -19.17 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.83 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -16.54 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.34 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -11.98 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -12.85 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -17.48 accept 0.00
# Best Sample: 4 log probability -0.038
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/15/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/15/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.81 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.66 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.74 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.82 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.61 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.84 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.91 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.52 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.18 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.65 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.94 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -10.91 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.54 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.77 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.36 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.47 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.35 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.97 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.56 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.35 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -4.31 accept 0.01
# Time 17 0.99 and 1.01 log_ratio -3.92 accept 0.02
# Time 17 1.02 and 1.04 log_ratio -4.66 accept 0.01
# Best Sample: 7 log probability -0.008
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/16/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/16/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.78 accept 0.46
# Time 221 0.99 and 1.01 log_ratio -1.64 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.81 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.72 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.73 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.63 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.95 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.13 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.63 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.06 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -15.04 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.35 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.26 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.38 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -18.18 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.33 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.98 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.78 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -18.49 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.19 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -23.08 accept 0.00
# Time 17 0.96 and 0.97 log_ratio 0.00 accept 1.00
# Time 17 0.99 and 1.01 log_ratio -16.87 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -31.92 accept 0.00
# Best Sample: 6 log probability -12.155
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/17/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/17/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.89 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.87 accept 0.15
# Time 221 1.02 and 1.04 log_ratio -0.84 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.81 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.81 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.79 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.54 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.10 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.30 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.93 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.89 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.74 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.57 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.78 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.41 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.80 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.65 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.57 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.48 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.91 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.30 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -13.26 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -10.36 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -11.94 accept 0.00
# Best Sample: 3 log probability -0.436
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/18/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/18/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.78 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -1.02 accept 0.36
# Time 187 0.95 and 0.96 log_ratio -3.54 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.87 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.86 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.64 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.26 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.75 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.00 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.82 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.84 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.69 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.90 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.28 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.50 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.46 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -15.05 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -14.17 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.82 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.88 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.02 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -8.33 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.38 accept 0.00
# Best Sample: 0 log probability -0.020
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/19/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/19/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.72 accept 0.18
# Time 221 1.02 and 1.04 log_ratio -0.80 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.70 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -6.11 accept 0.00
# Time 187 1.01 and 1.02 log_ratio -3.72 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.60 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -8.17 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.61 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.09 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.56 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -14.81 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.52 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.57 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.17 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -40.13 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.59 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.92 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -26.53 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.70 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.83 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.26 accept 0.04
# Time 17 0.99 and 1.01 log_ratio -24.84 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.99 accept 0.00
# Best Sample: 7 log probability -4.793
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/20/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/20/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.89 accept 0.41
# Time 221 0.99 and 1.01 log_ratio -1.67 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.69 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.81 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.91 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.76 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.29 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.32 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.90 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -14.59 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.97 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.68 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.19 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -18.21 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -35.17 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.63 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.98 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.10 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -17.59 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.16 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -50.15 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -7.74 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -13.30 accept 0.00
# Best Sample: 3 log probability -4.216
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/21/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/21/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.83 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.60 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.85 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.87 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.59 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.79 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.02 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.67 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.27 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.40 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.64 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -11.55 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.98 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -13.14 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -14.56 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -29.45 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -18.37 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.43 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.50 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.99 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.97 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -15.18 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -12.47 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -25.75 accept 0.00
# Best Sample: 1 log probability -0.287
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/22/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/22/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.80 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -1.53 accept 0.22
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.66 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.02 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.69 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.94 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.06 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -17.04 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.54 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.06 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.96 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.39 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.27 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.45 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.44 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -14.70 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.06 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -18.06 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -15.58 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.72 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -2.49 accept 0.08
# Time 17 0.99 and 1.01 log_ratio -27.48 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -3.59 accept 0.03
# Best Sample: 5 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/23/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/23/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.84 accept 0.16
# Time 221 1.02 and 1.04 log_ratio -0.81 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.76 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.85 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.71 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.69 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.07 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.24 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.33 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.12 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.22 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.99 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -11.68 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.02 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -32.71 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.85 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -20.92 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.45 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -18.40 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.37 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -13.01 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -35.23 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -7.64 accept 0.00
# Best Sample: 3 log probability -0.067
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/24/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/24/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.77 accept 0.46
# Time 221 0.99 and 1.01 log_ratio -1.56 accept 0.21
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.58 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.82 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.83 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.87 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.92 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.49 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.96 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.71 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.57 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.65 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.76 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -19.53 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -36.59 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.46 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.21 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.89 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -21.42 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -26.58 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -10.26 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -27.41 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -9.52 accept 0.00
# Best Sample: 0 log probability -20.480
# ...
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.79 accept 0.45
# Time 221 0.99 and 1.01 log_ratio -2.94 accept 0.05
# Time 221 1.02 and 1.04 log_ratio -0.87 accept 0.42
# Time 187 0.95 and 0.96 log_ratio -3.58 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.84 accept 0.01
# Time 187 1.01 and 1.02 log_ratio -3.43 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.76 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.24 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.91 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -7.60 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -11.33 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.23 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.93 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.57 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.70 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -33.24 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.18 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -14.80 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -16.52 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.99 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -13.97 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -50.53 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -12.65 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -5.71 accept 0.00
# Best Sample: 7 log probability -0.195
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/34/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/34/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.85 accept 0.43
# Time 221 0.99 and 1.01 log_ratio -1.66 accept 0.19
# Time 221 1.02 and 1.04 log_ratio -0.94 accept 0.39
# Time 187 0.95 and 0.96 log_ratio -3.69 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.63 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.70 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.65 accept 0.03
# Time 153 0.96 and 0.97 log_ratio -7.78 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.20 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.44 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.63 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.21 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.14 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -14.97 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.46 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.18 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.73 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -18.27 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.85 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -20.12 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -17.30 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -6.78 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -20.43 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -27.34 accept 0.00
# Best Sample: 2 log probability -2.394
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/35/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/35/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.86 accept 0.42
# Time 221 0.99 and 1.01 log_ratio -1.62 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.83 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.70 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -3.73 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.69 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -3.80 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.17 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.87 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -10.36 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.62 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -12.33 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.03 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.61 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.60 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -29.07 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -17.48 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.35 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -15.22 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.18 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -16.24 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -22.81 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -14.07 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -21.34 accept 0.00
# Best Sample: 7 log probability -0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/36/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/36/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.83 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.62 accept 0.20
# Time 221 1.02 and 1.04 log_ratio -0.81 accept 0.45
# Time 187 0.95 and 0.96 log_ratio -3.85 accept 0.02
# Time 187 0.97 and 0.99 log_ratio -4.36 accept 0.01
# Time 187 1.01 and 1.02 log_ratio -3.57 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.83 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.16 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.82 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.19 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.37 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -14.22 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -11.93 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.25 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -17.46 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -34.32 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.30 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.31 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -22.15 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -14.60 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -27.80 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -16.18 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -6.93 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -4.51 accept 0.01
# Best Sample: 5 log probability -0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/37/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/37/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.76 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -0.78 accept 0.46
# Time 187 0.95 and 0.96 log_ratio -3.45 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.80 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -3.59 accept 0.03
# Time 187 1.04 and 1.05 log_ratio -3.82 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.72 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -16.39 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.08 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -13.19 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.13 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.78 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.44 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.25 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -38.47 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -15.00 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.99 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -17.66 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.07 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -20.50 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -7.70 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -24.07 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -10.61 accept 0.00
# Best Sample: 0 log probability -0.572
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/38/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/38/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.82 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.80 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -0.82 accept 0.44
# Time 187 0.95 and 0.96 log_ratio -3.62 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -4.01 accept 0.02
# Time 187 1.01 and 1.02 log_ratio -4.26 accept 0.01
# Time 187 1.04 and 1.05 log_ratio -3.96 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -7.86 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -29.62 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.08 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.25 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -17.13 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -13.11 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.30 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -15.79 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -39.13 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -16.78 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -17.92 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.02 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -19.62 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -19.05 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -3.64 accept 0.03
# Time 17 0.99 and 1.01 log_ratio -32.98 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -8.94 accept 0.00
# Best Sample: 0 log probability -2.088
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/39/rollout.png
# Time 255 0.95 and 0.96 log_ratio 0.00 accept 1.00
# Time 255 0.97 and 0.99 log_ratio 0.00 accept 1.00
# Time 255 1.01 and 1.02 log_ratio 0.00 accept 1.00
# Time 255 1.04 and 1.05 log_ratio 0.00 accept 1.00
# Time 221 0.96 and 0.97 log_ratio -0.83 accept 0.44
# Time 221 0.99 and 1.01 log_ratio -1.75 accept 0.17
# Time 221 1.02 and 1.04 log_ratio -0.83 accept 0.43
# Time 187 0.95 and 0.96 log_ratio -3.69 accept 0.03
# Time 187 0.97 and 0.99 log_ratio -3.44 accept 0.03
# Time 187 1.01 and 1.02 log_ratio -3.82 accept 0.02
# Time 187 1.04 and 1.05 log_ratio -4.05 accept 0.02
# Time 153 0.96 and 0.97 log_ratio -8.25 accept 0.00
# Time 153 0.99 and 1.01 log_ratio -15.99 accept 0.00
# Time 153 1.02 and 1.04 log_ratio -8.13 accept 0.00
# Time 119 0.95 and 0.96 log_ratio -12.49 accept 0.00
# Time 119 0.97 and 0.99 log_ratio -13.19 accept 0.00
# Time 119 1.01 and 1.02 log_ratio -12.93 accept 0.00
# Time 119 1.04 and 1.05 log_ratio -12.71 accept 0.00
# Time 85 0.96 and 0.97 log_ratio -16.92 accept 0.00
# Time 85 0.99 and 1.01 log_ratio -31.53 accept 0.00
# Time 85 1.02 and 1.04 log_ratio -20.91 accept 0.00
# Time 51 0.95 and 0.96 log_ratio -16.85 accept 0.00
# Time 51 0.97 and 0.99 log_ratio -20.35 accept 0.00
# Time 51 1.01 and 1.02 log_ratio -27.13 accept 0.00
# Time 51 1.04 and 1.05 log_ratio -15.52 accept 0.00
# Time 17 0.96 and 0.97 log_ratio -16.16 accept 0.00
# Time 17 0.99 and 1.01 log_ratio -18.04 accept 0.00
# Time 17 1.02 and 1.04 log_ratio -35.62 accept 0.00
# Best Sample: 4 log probability -0.052
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-11 15:20:01/40/rollout.png
# Success Rate: 72.5, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14a92551cb80>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14a9309987c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14a9309773c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14a92f1d6680>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14a9309987c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14a9309773c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x14a92551cb80>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14a9309987c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14a9181c5240>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x14a92f1d6680>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x14a9309987c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x14a9181c5240>,
# 	),
# 	result = 0
# )
