# %%
# !MUJOCO_GL=egl srun python ~/STEER/pointmaze/run.py --dataset pointmaze-giant-navigate-v0 --lam_start 0.95 --lam_end 1.05 --replica_exchange --n_particles 8 --device cuda
# Out:
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card4: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card3: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# [ utils/setup ] Reading config: config.pointmaze:pointmaze_giant_navigate_v0
# [ utils/setup ] Using overrides | config: config.pointmaze | dataset: pointmaze_giant_navigate_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H400_T256
# [ utils/setup ] Setting exp_name to: plans/release_H400_T256_LimitsNormalizer_b1_condFalse
# [ utils/setup ] Saved args to logs/pointmaze-giant-navigate-v0/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/0/args.json
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/dataset_config.pkl
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: pointmaze-giant-navigate-v0
#     horizon: 400
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     termination_penalty: None
#     use_padding: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/render_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.PointMazeRenderer'>
#     env: pointmaze-giant-navigate-v0
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/model_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.temporal.TemporalUnet'>
#     cond_dim: 2
#     dim_mults: (1, 4, 8)
#     horizon: 424
#     transition_dim: 4
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/diffusion_config.pkl
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 400
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 2
#     predict_epsilon: False
#
# [ utils/serialization ] Loaded config from logs/pointmaze-giant-navigate-v0/diffusion/H400_T256/trainer_config.pkl
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 40000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs/pointmaze-giant-navigate-v0/diffusion/H400_T256
#     sample_freq: 1000
#     save_freq: 1000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ datasets/buffer ] Finalized replay buffer | 1500 episodes
# [ datasets/buffer ] Fields:
#     observations: (1500, 40000, 2)
#     actions: (1500, 40000, 2)
#     terminals: (1500, 40000, 1)
#     next_observations: (1500, 40000, 2)
#     normed_observations: (1500, 40000, 2)
#     normed_actions: (1500, 40000, 2)
# [ models/temporal ] Channel dimensions: [(4, 32), (32, 128), (128, 256)]
# [(4, 32), (32, 128), (128, 256)]
#
# [ utils/serialization ] Loading model epoch: 1200000
#
# /n/home00/zoewu/STEER/pointmaze/diffuser/utils/training.py:161: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(loadpath, map_location='cpu')
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 2 log probability -0.003
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/1/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/1/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 1 log probability -0.042
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/2/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/2/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 4 log probability -0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/3/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/3/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 4 log probability -0.268
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/4/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/4/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability -2.037
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/5/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/5/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/6/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/6/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 4 log probability -0.345
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/7/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/7/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability -0.036
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/8/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/8/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 5 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/9/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/9/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 6 log probability -0.005
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/10/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/10/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/11/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/11/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability -0.411
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/12/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/12/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 6 log probability -0.279
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/13/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/13/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 6 log probability -2.388
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/14/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/14/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 4 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/15/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/15/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 0 log probability -0.004
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/16/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/16/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability 0.000
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/17/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/17/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# ...
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 1 log probability -11.915
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/36/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/36/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 3 log probability -0.210
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/37/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/37/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 6 log probability -2.572
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/38/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/38/rollout.png
# Time 255 i 0 lam_t 0.99997 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00003 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 0.99999 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99997 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 0.99999 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99998 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99997 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 0.99999 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 1.00001 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99998 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99997 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 0.99999 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99998 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 0.99997 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00003 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 1.00002 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 1.00000 log_ratio -0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99997 lam_s 0.99999 log_ratio -0.0000 accept 1.0000 swapped True
# Best Sample: 2 log probability -0.345
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/39/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/39/rollout.png
# Time 255 i 0 lam_t 1.00003 lam_s 1.00001 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 255 i 0 lam_t 0.99999 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00002 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 221 i 2 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00003 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00002 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 187 i 4 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00001 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00003 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 153 i 6 lam_t 1.00002 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00000 lam_s 0.99998 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00001 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00003 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 119 i 8 lam_t 1.00002 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00000 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00001 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 85 i 10 lam_t 1.00003 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 0.99998 lam_s 0.99997 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00000 lam_s 0.99999 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00001 lam_s 1.00000 log_ratio 0.0000 accept 1.0000 swapped True
# Time 51 i 12 lam_t 1.00003 lam_s 1.00002 log_ratio 0.0000 accept 1.0000 swapped True
# Best Sample: 2 log probability -0.012
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/40/0.png
# Saved 1 samples to: logs/pointmaze-giant-navigate-v0/inference/plans/release_H400_T256_LimitsNormalizer_b1_condFalse/2026-07-12 19:57:54/40/rollout.png
# Success Rate: 80.0, Average Compute: 256.0
# Exception ignored in: <function OffScreenViewer.__del__ at 0x15164cab0ca0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1516581ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1516581cb3c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x1516571367a0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1516581ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1516581cb3c0>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function OffScreenViewer.__del__ at 0x15164cab0ca0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 204, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 201, in free
#     self.opengl_context.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1516581ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1515f6119240>,
# 	),
# 	result = 0
# )
# Exception ignored in: <function GLContext.__del__ at 0x1516571367a0>
# Traceback (most recent call last):
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 138, in __del__
#     self.free()
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/mujoco/egl/__init__.py", line 133, in free
#     EGL.eglDestroyContext(EGL_DISPLAY, self._context)
#   File "/n/home00/zoewu/.conda/envs/maze/lib/python3.10/site-packages/OpenGL/error.py", line 230, in glCheckError
#     raise self._errorClass(
# OpenGL.raw.EGL._errors.EGLError: EGLError(
# 	err = EGL_NOT_INITIALIZED,
# 	baseOperation = eglDestroyContext,
# 	cArguments = (
# 		<OpenGL._opaque.EGLDisplay_pointer object at 0x1516581ec7c0>,
# 		<OpenGL._opaque.EGLContext_pointer object at 0x1515f6119240>,
# 	),
# 	result = 0
# )
